# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score, average_precision_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from rdkit import Chem
from rdkit.Chem import AllChem, QED, DataStructs
import joblib
import os

# 데이터 로드 및 전처리
df = pd.read_csv('/data/home/dbswn0814/2025JCM/data/single task/sto_data.csv')

def preprocess_dataframe(df):
    df_copy = df.copy()
    df_copy.reset_index(drop=True, inplace=True)
    mols, none_list = [], []
    for i in range(len(df_copy)):
        smiles = str(df_copy.loc[i, 'SMILES'])
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            try:
                Chem.SanitizeMol(mol)
                mols.append(mol)
            except:
                none_list.append(i)
                print(f'Index {i}: 유효하지 않은 SMILES, 제외')
        else:
            none_list.append(i)
            print(f'Index {i}: None SMILES, 제외')
    if none_list:
        df_copy.drop(none_list, inplace=True)
        df_copy.reset_index(drop=True, inplace=True)
    return df_copy, mols

# 전처리 실행
df_clean, mols = preprocess_dataframe(df)

# Morgan Fingerprint 생성
fps = [AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024) for mol in mols]
arr_list = []
for bit in fps:
    arr = np.zeros((1024,), dtype=np.int8)
    DataStructs.ConvertToNumpyArray(bit, arr)
    arr_list.append(arr)
x_fingerprint = np.array(arr_list, dtype=np.float32)

# QED 속성 계산 및 스케일링
qe_props = [QED.properties(mol) for mol in mols]
qe_df = pd.DataFrame(qe_props)
scaler = StandardScaler()
qe_scaled = scaler.fit_transform(qe_df)
qe_scaled_df = pd.DataFrame(qe_scaled, columns=qe_df.columns)

# 최종 Feature 결합
features = np.hstack((x_fingerprint, qe_scaled_df.values))
final_df = pd.concat([pd.DataFrame(features), df_clean['sto'].reset_index(drop=True)], axis=1)
final_df.dropna(inplace=True)

X = final_df.drop('sto', axis=1).values
y = final_df['sto'].values

# K-Fold 외부 검증 설정
n_splits = 20
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)

save_dir = './grid_search'
os.makedirs(save_dir, exist_ok=True)

fold = 1
for train_idx, test_idx in outer_cv.split(X, y):
    print(f'=== Fold {fold} ===')
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    
    # Test 데이터 저장
    test_data = {'features': torch.tensor(X_test), 'labels': torch.tensor(y_test)}
    test_save_path = os.path.join(save_dir, f'SVM_test_fold{fold}.pt')
    torch.save(test_data, test_save_path)
    print(f'Test : {test_save_path}')
    
    # Train/Validation 분리
    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=0)
    for tr_idx, val_idx in sss.split(X_train, y_train):
        X_tr, X_val = X_train[tr_idx], X_train[val_idx]
        y_tr, y_val = y_train[tr_idx], y_train[val_idx]

    # Train/Val 데이터 저장
    train_save_path = os.path.join(save_dir, f'SVM_train_fold{fold}.pt')
    torch.save({'features': torch.tensor(X_tr), 'labels': torch.tensor(y_tr)}, train_save_path)
    print(f'Train : {train_save_path}')
    
    val_save_path = os.path.join(save_dir, f'SVM_val_fold{fold}.pt')
    torch.save({'features': torch.tensor(X_val), 'labels': torch.tensor(y_val)}, val_save_path)
    print(f'Validation : {val_save_path}')
    
    # 불균형 처리: class_weight 계산
    neg_count = np.sum(y_tr == 0)
    pos_count = np.sum(y_tr == 1)
    scale_pos_weight = neg_count / pos_count

    # Inner CV 및 Grid Search 설정 (SVM)
    inner_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    param_grid = {
        'C': [0.1, 1, 10],
        'kernel': ['linear', 'rbf'],
        'gamma': ['scale', 'auto']
    }
    base_model = SVC(
        probability=True,
        class_weight={0: 1, 1: scale_pos_weight},
        random_state=42
    )
    grid_search = GridSearchCV(
        base_model,
        param_grid,
        cv=inner_cv,
        scoring='roc_auc',
        n_jobs=-1
    )

    # 하이퍼파라미터 탐색
    grid_search.fit(X_tr, y_tr)
    best_model = grid_search.best_estimator_
    print('Best params:', grid_search.best_params_)

    # Validation 데이터에서 평가
    y_val_pred = best_model.predict(X_val)
    y_val_proba = best_model.predict_proba(X_val)[:, 1]
    val_metrics = {
        'accuracy': accuracy_score(y_val, y_val_pred),
        'roc_auc': roc_auc_score(y_val, y_val_proba),
        'avg_precision': average_precision_score(y_val, y_val_proba),
        'precision': precision_score(y_val, y_val_pred),
        'recall': recall_score(y_val, y_val_pred),
        'f1': f1_score(y_val, y_val_pred)
    }
    print(f'Validation Metrics: {val_metrics}')
    joblib.dump(val_metrics, os.path.join(save_dir, f'SVM_val_metrics_fold{fold}.pkl'))

    # 최적 모델 저장
    model_path = os.path.join(save_dir, f'svm_grid_fold{fold}.pkl')
    joblib.dump(best_model, model_path)
    print(f'Fold {fold} save: {model_path}\n')

    fold += 1

print('fin.')
# Out:
# === Fold 1 ===
# Test : ./grid_search/SVM_test_fold1.pt
# Train : ./grid_search/SVM_train_fold1.pt
# Validation : ./grid_search/SVM_val_fold1.pt
# Best params: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.5151515151515151, 'roc_auc': 0.5333333333333333, 'avg_precision': 0.6514858840804018, 'precision': 0.6, 'recall': 0.3333333333333333, 'f1': 0.42857142857142855}
# Fold 1 save: ./grid_search/svm_grid_fold1.pkl
#
# === Fold 2 ===
# Test : ./grid_search/SVM_test_fold2.pt
# Train : ./grid_search/SVM_train_fold2.pt
# Validation : ./grid_search/SVM_val_fold2.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.48484848484848486, 'roc_auc': 0.7296296296296296, 'avg_precision': 0.7615835257619146, 'precision': 0.5454545454545454, 'recall': 0.3333333333333333, 'f1': 0.41379310344827586}
# Fold 2 save: ./grid_search/svm_grid_fold2.pkl
#
# === Fold 3 ===
# Test : ./grid_search/SVM_test_fold3.pt
# Train : ./grid_search/SVM_train_fold3.pt
# Validation : ./grid_search/SVM_val_fold3.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6666666666666666, 'roc_auc': 0.7666666666666667, 'avg_precision': 0.8042793568297973, 'precision': 0.7333333333333333, 'recall': 0.6111111111111112, 'f1': 0.6666666666666666}
# Fold 3 save: ./grid_search/svm_grid_fold3.pkl
#
# === Fold 4 ===
# Test : ./grid_search/SVM_test_fold4.pt
# Train : ./grid_search/SVM_train_fold4.pt
# Validation : ./grid_search/SVM_val_fold4.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.696969696969697, 'roc_auc': 0.7962962962962963, 'avg_precision': 0.8309804719608641, 'precision': 0.75, 'recall': 0.6666666666666666, 'f1': 0.7058823529411765}
# Fold 4 save: ./grid_search/svm_grid_fold4.pkl
#
# === Fold 5 ===
# Test : ./grid_search/SVM_test_fold5.pt
# Train : ./grid_search/SVM_train_fold5.pt
# Validation : ./grid_search/SVM_val_fold5.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6666666666666666, 'roc_auc': 0.7944444444444445, 'avg_precision': 0.7571339075441242, 'precision': 0.7333333333333333, 'recall': 0.6111111111111112, 'f1': 0.6666666666666666}
# Fold 5 save: ./grid_search/svm_grid_fold5.pkl
#
# === Fold 6 ===
# Test : ./grid_search/SVM_test_fold6.pt
# Train : ./grid_search/SVM_train_fold6.pt
# Validation : ./grid_search/SVM_val_fold6.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.696969696969697, 'roc_auc': 0.7907407407407406, 'avg_precision': 0.824542618812989, 'precision': 0.7857142857142857, 'recall': 0.6111111111111112, 'f1': 0.6875000000000001}
# Fold 6 save: ./grid_search/svm_grid_fold6.pkl
#
# === Fold 7 ===
# Test : ./grid_search/SVM_test_fold7.pt
# Train : ./grid_search/SVM_train_fold7.pt
# Validation : ./grid_search/SVM_val_fold7.pt
# Best params: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.696969696969697, 'roc_auc': 0.7555555555555555, 'avg_precision': 0.8123432744955382, 'precision': 0.7222222222222222, 'recall': 0.7222222222222222, 'f1': 0.7222222222222222}
# Fold 7 save: ./grid_search/svm_grid_fold7.pkl
#
# === Fold 8 ===
# Test : ./grid_search/SVM_test_fold8.pt
# Train : ./grid_search/SVM_train_fold8.pt
# Validation : ./grid_search/SVM_val_fold8.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6666666666666666, 'roc_auc': 0.7592592592592593, 'avg_precision': 0.7576778048013328, 'precision': 0.7333333333333333, 'recall': 0.6111111111111112, 'f1': 0.6666666666666666}
# Fold 8 save: ./grid_search/svm_grid_fold8.pkl
#
# === Fold 9 ===
# Test : ./grid_search/SVM_test_fold9.pt
# Train : ./grid_search/SVM_train_fold9.pt
# Validation : ./grid_search/SVM_val_fold9.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.5151515151515151, 'roc_auc': 0.6370370370370371, 'avg_precision': 0.6378047886161922, 'precision': 0.5833333333333334, 'recall': 0.3888888888888889, 'f1': 0.4666666666666666}
# Fold 9 save: ./grid_search/svm_grid_fold9.pkl
#
# === Fold 10 ===
# Test : ./grid_search/SVM_test_fold10.pt
# Train : ./grid_search/SVM_train_fold10.pt
# Validation : ./grid_search/SVM_val_fold10.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.7575757575757576, 'roc_auc': 0.8481481481481481, 'avg_precision': 0.8646772607814921, 'precision': 0.8571428571428571, 'recall': 0.6666666666666666, 'f1': 0.75}
# Fold 10 save: ./grid_search/svm_grid_fold10.pkl
#
# === Fold 11 ===
# Test : ./grid_search/SVM_test_fold11.pt
# Train : ./grid_search/SVM_train_fold11.pt
# Validation : ./grid_search/SVM_val_fold11.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6363636363636364, 'roc_auc': 0.7, 'avg_precision': 0.7274315682380355, 'precision': 0.6875, 'recall': 0.6111111111111112, 'f1': 0.6470588235294118}
# Fold 11 save: ./grid_search/svm_grid_fold11.pkl
#
# === Fold 12 ===
# Test : ./grid_search/SVM_test_fold12.pt
# Train : ./grid_search/SVM_train_fold12.pt
# Validation : ./grid_search/SVM_val_fold12.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6060606060606061, 'roc_auc': 0.7259259259259259, 'avg_precision': 0.7963478986123913, 'precision': 0.631578947368421, 'recall': 0.6666666666666666, 'f1': 0.6486486486486486}
# Fold 12 save: ./grid_search/svm_grid_fold12.pkl
#
# === Fold 13 ===
# Test : ./grid_search/SVM_test_fold13.pt
# Train : ./grid_search/SVM_train_fold13.pt
# Validation : ./grid_search/SVM_val_fold13.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6363636363636364, 'roc_auc': 0.7037037037037037, 'avg_precision': 0.6722322897887689, 'precision': 0.75, 'recall': 0.5, 'f1': 0.6}
# Fold 13 save: ./grid_search/svm_grid_fold13.pkl
#
# === Fold 14 ===
# Test : ./grid_search/SVM_test_fold14.pt
# Train : ./grid_search/SVM_train_fold14.pt
# Validation : ./grid_search/SVM_val_fold14.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.696969696969697, 'roc_auc': 0.8629629629629629, 'avg_precision': 0.8774684659373604, 'precision': 0.7857142857142857, 'recall': 0.6111111111111112, 'f1': 0.6875000000000001}
# Fold 14 save: ./grid_search/svm_grid_fold14.pkl
#
# === Fold 15 ===
# Test : ./grid_search/SVM_test_fold15.pt
# Train : ./grid_search/SVM_train_fold15.pt
# Validation : ./grid_search/SVM_val_fold15.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.7272727272727273, 'roc_auc': 0.7851851851851852, 'avg_precision': 0.8137896913202952, 'precision': 0.7647058823529411, 'recall': 0.7222222222222222, 'f1': 0.7428571428571428}
# Fold 15 save: ./grid_search/svm_grid_fold15.pkl
#
# === Fold 16 ===
# Test : ./grid_search/SVM_test_fold16.pt
# Train : ./grid_search/SVM_train_fold16.pt
# Validation : ./grid_search/SVM_val_fold16.pt
# Best params: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.7272727272727273, 'roc_auc': 0.7814814814814816, 'avg_precision': 0.8016945198683986, 'precision': 0.7647058823529411, 'recall': 0.7222222222222222, 'f1': 0.7428571428571428}
# Fold 16 save: ./grid_search/svm_grid_fold16.pkl
#
# === Fold 17 ===
# Test : ./grid_search/SVM_test_fold17.pt
# Train : ./grid_search/SVM_train_fold17.pt
# Validation : ./grid_search/SVM_val_fold17.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.5757575757575758, 'roc_auc': 0.662962962962963, 'avg_precision': 0.7210377033080233, 'precision': 0.625, 'recall': 0.5555555555555556, 'f1': 0.5882352941176471}
# Fold 17 save: ./grid_search/svm_grid_fold17.pkl
#
# === Fold 18 ===
# Test : ./grid_search/SVM_test_fold18.pt
# Train : ./grid_search/SVM_train_fold18.pt
# Validation : ./grid_search/SVM_val_fold18.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6666666666666666, 'roc_auc': 0.774074074074074, 'avg_precision': 0.7877987390242293, 'precision': 0.7333333333333333, 'recall': 0.6111111111111112, 'f1': 0.6666666666666666}
# Fold 18 save: ./grid_search/svm_grid_fold18.pkl
#
# === Fold 19 ===
# Test : ./grid_search/SVM_test_fold19.pt
# Train : ./grid_search/SVM_train_fold19.pt
# Validation : ./grid_search/SVM_val_fold19.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.5757575757575758, 'roc_auc': 0.6833333333333333, 'avg_precision': 0.7317501361154611, 'precision': 0.6428571428571429, 'recall': 0.5, 'f1': 0.5625000000000001}
# Fold 19 save: ./grid_search/svm_grid_fold19.pkl
#
# === Fold 20 ===
# Test : ./grid_search/SVM_test_fold20.pt
# Train : ./grid_search/SVM_train_fold20.pt
# Validation : ./grid_search/SVM_val_fold20.pt
# Best params: {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# Validation Metrics: {'accuracy': 0.6666666666666666, 'roc_auc': 0.7370370370370369, 'avg_precision': 0.7778117262729737, 'precision': 0.7058823529411765, 'recall': 0.6666666666666666, 'f1': 0.6857142857142857}
# Fold 20 save: ./grid_search/svm_grid_fold20.pkl
#
# fin.
