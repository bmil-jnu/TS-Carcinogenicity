# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import random
import time
from math import sqrt
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import (matthews_corrcoef, accuracy_score, confusion_matrix, 
                             roc_auc_score, average_precision_score, 
                             cohen_kappa_score, balanced_accuracy_score, 
                             roc_curve, auc, precision_recall_curve)
from bayes_opt import BayesianOptimization
from utils import (
    single_task, EarlyStopping, train_single_task, val_single_task, test_single_task,
    FocalLoss, load_data, CustomDataset)
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from torch.utils.data import TensorDataset,Subset, DataLoader, Dataset as TorchDataset  # 일반적인 PyTorch의 Dataset 사용
from torch_geometric.data import InMemoryDataset, DataLoader, Batch, Dataset, Data, data
from collections import defaultdict
torch.use_deterministic_algorithms(True, warn_only=True)
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit, ParameterGrid
import pandas as pd
import matplotlib.pyplot as plt  # 시각화를 위해 matplotlib도 필요합니다.
import warnings
warnings.filterwarnings("ignore")

# %%
def set_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    # 시드 고정
    torch.manual_seed(seed)  # PyTorch 난수 시드
    torch.cuda.manual_seed(seed)  # CUDA 난수 시드
    torch.cuda.manual_seed_all(seed)  # 멀티 GPU 사용 시 시드 고정
    
    # CuDNN을 결정적 모드로 설정
    torch.backends.cudnn.enabled = False
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    # Numpy 및 파이썬 기본 random 모듈의 시드 고정
    np.random.seed(seed)
    random.seed(seed)
    

# 시드 고정 호출
set_seed(0)

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    
rng = np.random.default_rng(8888)
rfloat = rng.random()

# %%
def evaluate_model(model, device, data_loader):
    model.eval()
    y_true = []
    y_scores = []
    
    with torch.no_grad():
        for batch in data_loader:
            data = batch.to(device)
            labels = batch.y.to(device)
            outputs, _ = model(data)
            outputs = outputs.view_as(labels)
            probs = torch.sigmoid(outputs).cpu().numpy()
            y_scores.extend(probs.flatten())
            y_true.extend(labels.cpu().numpy().flatten())
    
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)
    
    # -1 라벨 제거
    mask = y_true != -1
    y_true = y_true[mask]
    y_scores = y_scores[mask]
    
    try:
        auc = roc_auc_score(y_true, y_scores)
    except ValueError:
        auc = np.nan  # AUC를 계산할 수 없는 경우

    try:
        pr_auc = average_precision_score(y_true, y_scores)
    except ValueError:
        pr_auc = np.nan  # PR AUC를 계산할 수 없는 경우

    y_pred_labels = (y_scores >= 0.5).astype(int)
    accuracy = accuracy_score(y_true, y_pred_labels)
    
    return auc, pr_auc, accuracy

# %%
def main():
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    K = 20  # Number of folds
    
    # Define the hyperparameter grid
    param_grid = {
        'output_dim': [8, 16],
        'dropout': [0.2],
        'batch_size': [8],
        'lr': [0.001, 0.0001],
        'wd': [1e-06, 1e-05, 1e-04],
    }
    
    grid = list(ParameterGrid(param_grid))
    total_combinations = len(grid)
    print(f"Total hyperparameter combinations to evaluate: {total_combinations}")
    
    # Load the dataset once
    dataset = load_data("sto")
    X = dataset.data_x
    y = dataset.data_y
    
    # Initialize K-Fold
    kf = StratifiedKFold(n_splits=K, shuffle=True, random_state=2)
    
    # Prepare to store all results
    all_results = []
    
    # Iterate over each hyperparameter combination
    for idx, params in enumerate(grid, 1):
        print(f"\n===== Evaluating Hyperparameter Combination {idx}/{total_combinations} =====")
        print(f"Parameters: {params}")
        
        # To store results for all folds for the current hyperparameter combination
        fold_results = []
        
        for fold, (train_indices, test_indices) in enumerate(kf.split(X, y), 1):
            print(f"\n--- Fold {fold}/{K} ---")
            
            # Stratified Shuffle Split for validation set
            sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=1)
            train_idx, val_idx = next(sss.split(np.zeros(len(train_indices)), y[train_indices]))
            
            # Subset datasets
            train_subset = Subset(dataset, train_indices[train_idx])
            val_subset = Subset(dataset, train_indices[val_idx])
            test_subset = Subset(dataset, test_indices)
            
            # DataLoaders
            batch_size = params['batch_size']
            train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, collate_fn=Batch.from_data_list)
            val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, collate_fn=Batch.from_data_list)
            test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, collate_fn=Batch.from_data_list)
            
            # Initialize the model with current hyperparameters
            model = single_task(
                num_features=75, 
                n_heads1=2, 
                output_dim=params['output_dim'],
                dropout=params['dropout']
            ).to(device)
            
            # Define Loss and Optimizer with current hyperparameters
            criterion = FocalLoss(alpha=0.25, gamma=4.0, reduction='mean')
            optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['wd'])
            
            # EarlyStopping setup
            checkpoint_path = f'/data/home/dbswn0814/2025JCM/model/single task/sto/weight/checkpoint_combination_{idx}_fold_{fold}.pt'
            early_stopping = EarlyStopping(patience=10, verbose=False, path=checkpoint_path, trace_func=lambda x: None)
            
            # Training Loop
            num_epochs = 1000
            best_epoch = 0
            for epoch in range(1, num_epochs + 1):
                train_loss = train_single_task(epoch, model, criterion, optimizer, device, train_loader)
                val_loss = val_single_task(epoch, model, criterion, device, val_loader)
    
#                 print(f"Epoch {epoch}/{num_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    
                # Early Stopping
                early_stopping(val_loss, model)
    
                if early_stopping.early_stop:
                    print(f"Early stopping triggered at epoch {epoch}. Best Val Loss: {early_stopping.val_loss_min:.4f}")
                    best_epoch = epoch
                    break
                best_epoch = epoch  # Update best epoch
    
            # Load the best model
            model.load_state_dict(torch.load(checkpoint_path))
            
            # Evaluate on Test Set
            test_loss = test_single_task(epoch, model, criterion, device, test_loader)
            test_auc, test_pr_auc, test_accuracy = evaluate_model(model, device, test_loader)
            
            print(f"Fold {fold} Results - Best Epoch: {best_epoch}, Val Loss: {early_stopping.val_loss_min:.4f}, Test Loss: {test_loss:.4f}, Test AUC: {test_auc:.4f}, PR AUC: {test_pr_auc:.4f}, Accuracy: {test_accuracy:.4f}")
            
            # Store fold results
            fold_result = {
                'Combination': idx,
                'Fold': fold,
                'Best_Epoch': best_epoch,
                'Best_Val_Loss': early_stopping.val_loss_min,
                'Test_Loss': test_loss,
                'Test_AUC': test_auc,
                'Test_PR_AUC': test_pr_auc,
                'Test_Accuracy': test_accuracy
            }
            fold_results.append(fold_result)
        
        # After all folds, compute average and std metrics
        test_losses = [fr['Test_Loss'] for fr in fold_results]
        test_aucs = [fr['Test_AUC'] for fr in fold_results]
        test_pr_aucs = [fr['Test_PR_AUC'] for fr in fold_results]
        test_accuracies = [fr['Test_Accuracy'] for fr in fold_results]
        
        mean_test_loss = np.mean(test_losses)
        std_test_loss = np.std(test_losses)
        mean_test_auc = np.mean(test_aucs)
        std_test_auc = np.std(test_aucs)
        mean_test_pr_auc = np.mean(test_pr_aucs)
        std_test_pr_auc = np.std(test_pr_aucs)
        mean_test_accuracy = np.mean(test_accuracies)
        std_test_accuracy = np.std(test_accuracies)
        
        # Append the overall results for the current combination
        combination_result = {
            'Combination': idx,
            **params,
            'Mean_Test_Loss': mean_test_loss,
            'Std_Test_Loss': std_test_loss,
            'Mean_Test_AUC': mean_test_auc,
            'Std_Test_AUC': std_test_auc,
            'Mean_Test_PR_AUC': mean_test_pr_auc,
            'Std_Test_PR_AUC': std_test_pr_auc,
            'Mean_Test_Accuracy': mean_test_accuracy,
            'Std_Test_Accuracy': std_test_accuracy
        }
        all_results.append(combination_result)
        
        # Optionally, print the results for the current combination
        print(f"\nCombination {idx} Results:")
        print(f"Mean Test Loss: {mean_test_loss:.4f} ± {std_test_loss:.4f}")
        print(f"Mean Test AUC: {mean_test_auc:.4f} ± {std_test_auc:.4f}")
        print(f"Mean Test PR AUC: {mean_test_pr_auc:.4f} ± {std_test_pr_auc:.4f}")
        print(f"Mean Test Accuracy: {mean_test_accuracy:.4f} ± {std_test_accuracy:.4f}")
    
    # After all combinations, save results to CSV
    results_df = pd.DataFrame(all_results)
    results_csv_path = 'single sto grid_search_results.csv'
    results_df.to_csv(results_csv_path, index=False)
    print(f"\nGrid search completed. Results saved to {results_csv_path}")
    
    # Optionally, visualize the results
    # Example: Plot Mean Test AUC for each combination
    plt.figure(figsize=(12, 6))
    plt.bar(range(len(all_results)), results_df['Mean_Test_AUC'], yerr=results_df['Std_Test_AUC'], capsize=5)
    plt.xlabel('Hyperparameter Combination')
    plt.ylabel('Mean Test AUC')
    plt.title('Grid Search: Mean Test AUC for Each Hyperparameter Combination')
    plt.xticks(range(len(all_results)), results_df['Combination'], rotation=90)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Total hyperparameter combinations to evaluate: 12
#
# ===== Evaluating Hyperparameter Combination 1/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 8, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0119
# ====> Epoch: 46 Average test Loss: 0.0128
# Fold 1 Results - Best Epoch: 46, Val Loss: 0.0119, Test Loss: 0.0128, Test AUC: 0.8250, PR AUC: 0.8740, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0097
# ====> Epoch: 38 Average test Loss: 0.0107
# Fold 2 Results - Best Epoch: 38, Val Loss: 0.0097, Test Loss: 0.0107, Test AUC: 0.8750, PR AUC: 0.9207, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 40. Best Val Loss: 0.0111
# ====> Epoch: 40 Average test Loss: 0.0131
# Fold 3 Results - Best Epoch: 40, Val Loss: 0.0111, Test Loss: 0.0131, Test AUC: 0.8000, PR AUC: 0.8689, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 49. Best Val Loss: 0.0118
# ====> Epoch: 49 Average test Loss: 0.0178
# Fold 4 Results - Best Epoch: 49, Val Loss: 0.0118, Test Loss: 0.0178, Test AUC: 0.5429, PR AUC: 0.6004, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0099
# ====> Epoch: 52 Average test Loss: 0.0118
# Fold 5 Results - Best Epoch: 52, Val Loss: 0.0099, Test Loss: 0.0118, Test AUC: 0.7857, PR AUC: 0.8437, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0097
# ====> Epoch: 52 Average test Loss: 0.0119
# Fold 6 Results - Best Epoch: 52, Val Loss: 0.0097, Test Loss: 0.0119, Test AUC: 0.7286, PR AUC: 0.7155, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0117
# ====> Epoch: 46 Average test Loss: 0.0215
# Fold 7 Results - Best Epoch: 46, Val Loss: 0.0117, Test Loss: 0.0215, Test AUC: 0.8750, PR AUC: 0.8603, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 31. Best Val Loss: 0.0125
# ====> Epoch: 31 Average test Loss: 0.0195
# Fold 8 Results - Best Epoch: 31, Val Loss: 0.0125, Test Loss: 0.0195, Test AUC: 0.5556, PR AUC: 0.7157, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 42. Best Val Loss: 0.0124
# ====> Epoch: 42 Average test Loss: 0.0217
# Fold 9 Results - Best Epoch: 42, Val Loss: 0.0124, Test Loss: 0.0217, Test AUC: 0.7431, PR AUC: 0.7577, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 26. Best Val Loss: 0.0151
# ====> Epoch: 26 Average test Loss: 0.0171
# Fold 10 Results - Best Epoch: 26, Val Loss: 0.0151, Test Loss: 0.0171, Test AUC: 0.6667, PR AUC: 0.6636, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0136
# ====> Epoch: 46 Average test Loss: 0.0101
# Fold 11 Results - Best Epoch: 46, Val Loss: 0.0136, Test Loss: 0.0101, Test AUC: 0.8681, PR AUC: 0.8447, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0153
# ====> Epoch: 30 Average test Loss: 0.0110
# Fold 12 Results - Best Epoch: 30, Val Loss: 0.0153, Test Loss: 0.0110, Test AUC: 0.8333, PR AUC: 0.8744, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 56. Best Val Loss: 0.0102
# ====> Epoch: 56 Average test Loss: 0.0162
# Fold 13 Results - Best Epoch: 56, Val Loss: 0.0102, Test Loss: 0.0162, Test AUC: 0.7222, PR AUC: 0.7946, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 32. Best Val Loss: 0.0147
# ====> Epoch: 32 Average test Loss: 0.0108
# Fold 14 Results - Best Epoch: 32, Val Loss: 0.0147, Test Loss: 0.0108, Test AUC: 0.7917, PR AUC: 0.7991, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 56. Best Val Loss: 0.0087
# ====> Epoch: 56 Average test Loss: 0.0129
# Fold 15 Results - Best Epoch: 56, Val Loss: 0.0087, Test Loss: 0.0129, Test AUC: 0.8125, PR AUC: 0.8773, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0155
# ====> Epoch: 30 Average test Loss: 0.0159
# Fold 16 Results - Best Epoch: 30, Val Loss: 0.0155, Test Loss: 0.0159, Test AUC: 0.7778, PR AUC: 0.7234, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0130
# ====> Epoch: 36 Average test Loss: 0.0139
# Fold 17 Results - Best Epoch: 36, Val Loss: 0.0130, Test Loss: 0.0139, Test AUC: 0.8750, PR AUC: 0.8871, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 42. Best Val Loss: 0.0128
# ====> Epoch: 42 Average test Loss: 0.0170
# Fold 18 Results - Best Epoch: 42, Val Loss: 0.0128, Test Loss: 0.0170, Test AUC: 0.6389, PR AUC: 0.7056, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0118
# ====> Epoch: 41 Average test Loss: 0.0155
# Fold 19 Results - Best Epoch: 41, Val Loss: 0.0118, Test Loss: 0.0155, Test AUC: 0.7361, PR AUC: 0.8106, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0117
# ====> Epoch: 35 Average test Loss: 0.0328
# Fold 20 Results - Best Epoch: 35, Val Loss: 0.0117, Test Loss: 0.0328, Test AUC: 0.8194, PR AUC: 0.7440, Accuracy: 0.5294
#
# Combination 1 Results:
# Mean Test Loss: 0.0157 ± 0.0052
# Mean Test AUC: 0.7636 ± 0.0965
# Mean Test PR AUC: 0.7941 ± 0.0846
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 2/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 8, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 28. Best Val Loss: 0.0156
# ====> Epoch: 28 Average test Loss: 0.0147
# Fold 1 Results - Best Epoch: 28, Val Loss: 0.0156, Test Loss: 0.0147, Test AUC: 0.8375, PR AUC: 0.8448, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0183
# ====> Epoch: 14 Average test Loss: 0.0183
# Fold 2 Results - Best Epoch: 14, Val Loss: 0.0183, Test Loss: 0.0183, Test AUC: 0.5000, PR AUC: 0.5556, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 34. Best Val Loss: 0.0117
# ====> Epoch: 34 Average test Loss: 0.0149
# Fold 3 Results - Best Epoch: 34, Val Loss: 0.0117, Test Loss: 0.0149, Test AUC: 0.7625, PR AUC: 0.7998, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0116
# ====> Epoch: 36 Average test Loss: 0.0179
# Fold 4 Results - Best Epoch: 36, Val Loss: 0.0116, Test Loss: 0.0179, Test AUC: 0.4429, PR AUC: 0.5604, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0103
# ====> Epoch: 39 Average test Loss: 0.0097
# Fold 5 Results - Best Epoch: 39, Val Loss: 0.0103, Test Loss: 0.0097, Test AUC: 0.8857, PR AUC: 0.9417, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 54. Best Val Loss: 0.0075
# ====> Epoch: 54 Average test Loss: 0.0176
# Fold 6 Results - Best Epoch: 54, Val Loss: 0.0075, Test Loss: 0.0176, Test AUC: 0.7429, PR AUC: 0.7634, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 59. Best Val Loss: 0.0111
# ====> Epoch: 59 Average test Loss: 0.0150
# Fold 7 Results - Best Epoch: 59, Val Loss: 0.0111, Test Loss: 0.0150, Test AUC: 0.7778, PR AUC: 0.7696, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0119
# ====> Epoch: 43 Average test Loss: 0.0154
# Fold 8 Results - Best Epoch: 43, Val Loss: 0.0119, Test Loss: 0.0154, Test AUC: 0.6250, PR AUC: 0.7306, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 33. Best Val Loss: 0.0130
# ====> Epoch: 33 Average test Loss: 0.0156
# Fold 9 Results - Best Epoch: 33, Val Loss: 0.0130, Test Loss: 0.0156, Test AUC: 0.7778, PR AUC: 0.8121, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 25. Best Val Loss: 0.0139
# ====> Epoch: 25 Average test Loss: 0.0163
# Fold 10 Results - Best Epoch: 25, Val Loss: 0.0139, Test Loss: 0.0163, Test AUC: 0.5139, PR AUC: 0.5661, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0126
# ====> Epoch: 36 Average test Loss: 0.0079
# Fold 11 Results - Best Epoch: 36, Val Loss: 0.0126, Test Loss: 0.0079, Test AUC: 0.9444, PR AUC: 0.9599, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 58. Best Val Loss: 0.0133
# ====> Epoch: 58 Average test Loss: 0.0089
# Fold 12 Results - Best Epoch: 58, Val Loss: 0.0133, Test Loss: 0.0089, Test AUC: 0.9444, PR AUC: 0.9658, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0108
# ====> Epoch: 46 Average test Loss: 0.0131
# Fold 13 Results - Best Epoch: 46, Val Loss: 0.0108, Test Loss: 0.0131, Test AUC: 0.7639, PR AUC: 0.8282, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0142
# ====> Epoch: 39 Average test Loss: 0.0100
# Fold 14 Results - Best Epoch: 39, Val Loss: 0.0142, Test Loss: 0.0100, Test AUC: 0.8889, PR AUC: 0.9017, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 22. Best Val Loss: 0.0146
# ====> Epoch: 22 Average test Loss: 0.0159
# Fold 15 Results - Best Epoch: 22, Val Loss: 0.0146, Test Loss: 0.0159, Test AUC: 0.7778, PR AUC: 0.7720, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0141
# ====> Epoch: 44 Average test Loss: 0.0169
# Fold 16 Results - Best Epoch: 44, Val Loss: 0.0141, Test Loss: 0.0169, Test AUC: 0.8472, PR AUC: 0.8497, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 32. Best Val Loss: 0.0176
# ====> Epoch: 32 Average test Loss: 0.0109
# Fold 17 Results - Best Epoch: 32, Val Loss: 0.0176, Test Loss: 0.0109, Test AUC: 0.8611, PR AUC: 0.8949, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 19. Best Val Loss: 0.0142
# ====> Epoch: 19 Average test Loss: 0.0187
# Fold 18 Results - Best Epoch: 19, Val Loss: 0.0142, Test Loss: 0.0187, Test AUC: 0.8472, PR AUC: 0.8623, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0127
# ====> Epoch: 35 Average test Loss: 0.0219
# Fold 19 Results - Best Epoch: 35, Val Loss: 0.0127, Test Loss: 0.0219, Test AUC: 0.6806, PR AUC: 0.7521, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0100
# ====> Epoch: 46 Average test Loss: 0.0240
# Fold 20 Results - Best Epoch: 46, Val Loss: 0.0100, Test Loss: 0.0240, Test AUC: 0.8750, PR AUC: 0.8376, Accuracy: 0.5294
#
# Combination 2 Results:
# Mean Test Loss: 0.0152 ± 0.0041
# Mean Test AUC: 0.7648 ± 0.1413
# Mean Test PR AUC: 0.7984 ± 0.1194
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 3/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 8, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 29. Best Val Loss: 0.0140
# ====> Epoch: 29 Average test Loss: 0.0142
# Fold 1 Results - Best Epoch: 29, Val Loss: 0.0140, Test Loss: 0.0142, Test AUC: 0.7625, PR AUC: 0.8134, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 93. Best Val Loss: 0.0098
# ====> Epoch: 93 Average test Loss: 0.0101
# Fold 2 Results - Best Epoch: 93, Val Loss: 0.0098, Test Loss: 0.0101, Test AUC: 0.8625, PR AUC: 0.9198, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 68. Best Val Loss: 0.0114
# ====> Epoch: 68 Average test Loss: 0.0199
# Fold 3 Results - Best Epoch: 68, Val Loss: 0.0114, Test Loss: 0.0199, Test AUC: 0.6125, PR AUC: 0.6560, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0115
# ====> Epoch: 41 Average test Loss: 0.0135
# Fold 4 Results - Best Epoch: 41, Val Loss: 0.0115, Test Loss: 0.0135, Test AUC: 0.7000, PR AUC: 0.7936, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 26. Best Val Loss: 0.0151
# ====> Epoch: 26 Average test Loss: 0.0143
# Fold 5 Results - Best Epoch: 26, Val Loss: 0.0151, Test Loss: 0.0143, Test AUC: 0.6571, PR AUC: 0.7441, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0138
# ====> Epoch: 43 Average test Loss: 0.0162
# Fold 6 Results - Best Epoch: 43, Val Loss: 0.0138, Test Loss: 0.0162, Test AUC: 0.6286, PR AUC: 0.6592, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 55. Best Val Loss: 0.0145
# ====> Epoch: 55 Average test Loss: 0.0224
# Fold 7 Results - Best Epoch: 55, Val Loss: 0.0145, Test Loss: 0.0224, Test AUC: 0.8333, PR AUC: 0.8127, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0127
# ====> Epoch: 57 Average test Loss: 0.0168
# Fold 8 Results - Best Epoch: 57, Val Loss: 0.0127, Test Loss: 0.0168, Test AUC: 0.6389, PR AUC: 0.7387, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 70. Best Val Loss: 0.0115
# ====> Epoch: 70 Average test Loss: 0.0161
# Fold 9 Results - Best Epoch: 70, Val Loss: 0.0115, Test Loss: 0.0161, Test AUC: 0.7222, PR AUC: 0.8054, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0171
# ====> Epoch: 27 Average test Loss: 0.0166
# Fold 10 Results - Best Epoch: 27, Val Loss: 0.0171, Test Loss: 0.0166, Test AUC: 0.6806, PR AUC: 0.7252, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 40. Best Val Loss: 0.0147
# ====> Epoch: 40 Average test Loss: 0.0120
# Fold 11 Results - Best Epoch: 40, Val Loss: 0.0147, Test Loss: 0.0120, Test AUC: 0.8750, PR AUC: 0.9354, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0159
# ====> Epoch: 27 Average test Loss: 0.0135
# Fold 12 Results - Best Epoch: 27, Val Loss: 0.0159, Test Loss: 0.0135, Test AUC: 0.9028, PR AUC: 0.9202, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0139
# ====> Epoch: 39 Average test Loss: 0.0173
# Fold 13 Results - Best Epoch: 39, Val Loss: 0.0139, Test Loss: 0.0173, Test AUC: 0.6736, PR AUC: 0.7263, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0146
# ====> Epoch: 43 Average test Loss: 0.0126
# Fold 14 Results - Best Epoch: 43, Val Loss: 0.0146, Test Loss: 0.0126, Test AUC: 0.7500, PR AUC: 0.7918, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 50. Best Val Loss: 0.0101
# ====> Epoch: 50 Average test Loss: 0.0141
# Fold 15 Results - Best Epoch: 50, Val Loss: 0.0101, Test Loss: 0.0141, Test AUC: 0.7917, PR AUC: 0.8752, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 32. Best Val Loss: 0.0147
# ====> Epoch: 32 Average test Loss: 0.0175
# Fold 16 Results - Best Epoch: 32, Val Loss: 0.0147, Test Loss: 0.0175, Test AUC: 0.8194, PR AUC: 0.8423, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0153
# ====> Epoch: 38 Average test Loss: 0.0109
# Fold 17 Results - Best Epoch: 38, Val Loss: 0.0153, Test Loss: 0.0109, Test AUC: 0.9583, PR AUC: 0.9675, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 22. Best Val Loss: 0.0163
# ====> Epoch: 22 Average test Loss: 0.0193
# Fold 18 Results - Best Epoch: 22, Val Loss: 0.0163, Test Loss: 0.0193, Test AUC: 0.7292, PR AUC: 0.7032, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0136
# ====> Epoch: 39 Average test Loss: 0.0221
# Fold 19 Results - Best Epoch: 39, Val Loss: 0.0136, Test Loss: 0.0221, Test AUC: 0.6806, PR AUC: 0.7791, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 53. Best Val Loss: 0.0087
# ====> Epoch: 53 Average test Loss: 0.0489
# Fold 20 Results - Best Epoch: 53, Val Loss: 0.0087, Test Loss: 0.0489, Test AUC: 0.8750, PR AUC: 0.8593, Accuracy: 0.5294
#
# Combination 3 Results:
# Mean Test Loss: 0.0174 ± 0.0079
# Mean Test AUC: 0.7577 ± 0.0992
# Mean Test PR AUC: 0.8034 ± 0.0879
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 4/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 16, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 33. Best Val Loss: 0.0145
# ====> Epoch: 33 Average test Loss: 0.0137
# Fold 1 Results - Best Epoch: 33, Val Loss: 0.0145, Test Loss: 0.0137, Test AUC: 0.8000, PR AUC: 0.8402, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0104
# ====> Epoch: 52 Average test Loss: 0.0140
# Fold 2 Results - Best Epoch: 52, Val Loss: 0.0104, Test Loss: 0.0140, Test AUC: 0.7750, PR AUC: 0.8452, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 34. Best Val Loss: 0.0109
# ====> Epoch: 34 Average test Loss: 0.0149
# Fold 3 Results - Best Epoch: 34, Val Loss: 0.0109, Test Loss: 0.0149, Test AUC: 0.7250, PR AUC: 0.8250, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0109
# ====> Epoch: 46 Average test Loss: 0.0140
# Fold 4 Results - Best Epoch: 46, Val Loss: 0.0109, Test Loss: 0.0140, Test AUC: 0.7143, PR AUC: 0.8308, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 51. Best Val Loss: 0.0095
# ====> Epoch: 51 Average test Loss: 0.0105
# Fold 5 Results - Best Epoch: 51, Val Loss: 0.0095, Test Loss: 0.0105, Test AUC: 0.8714, PR AUC: 0.9285, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 65. Best Val Loss: 0.0069
# ====> Epoch: 65 Average test Loss: 0.0119
# Fold 6 Results - Best Epoch: 65, Val Loss: 0.0069, Test Loss: 0.0119, Test AUC: 0.9000, PR AUC: 0.9327, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 50. Best Val Loss: 0.0128
# ====> Epoch: 50 Average test Loss: 0.0217
# Fold 7 Results - Best Epoch: 50, Val Loss: 0.0128, Test Loss: 0.0217, Test AUC: 0.8333, PR AUC: 0.8083, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 28. Best Val Loss: 0.0126
# ====> Epoch: 28 Average test Loss: 0.0185
# Fold 8 Results - Best Epoch: 28, Val Loss: 0.0126, Test Loss: 0.0185, Test AUC: 0.5833, PR AUC: 0.6822, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 33. Best Val Loss: 0.0130
# ====> Epoch: 33 Average test Loss: 0.0165
# Fold 9 Results - Best Epoch: 33, Val Loss: 0.0130, Test Loss: 0.0165, Test AUC: 0.7292, PR AUC: 0.7120, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0152
# ====> Epoch: 37 Average test Loss: 0.0165
# Fold 10 Results - Best Epoch: 37, Val Loss: 0.0152, Test Loss: 0.0165, Test AUC: 0.7222, PR AUC: 0.7432, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0115
# ====> Epoch: 41 Average test Loss: 0.0084
# Fold 11 Results - Best Epoch: 41, Val Loss: 0.0115, Test Loss: 0.0084, Test AUC: 0.9444, PR AUC: 0.9576, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0113
# ====> Epoch: 37 Average test Loss: 0.0105
# Fold 12 Results - Best Epoch: 37, Val Loss: 0.0113, Test Loss: 0.0105, Test AUC: 0.9167, PR AUC: 0.9436, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0107
# ====> Epoch: 44 Average test Loss: 0.0161
# Fold 13 Results - Best Epoch: 44, Val Loss: 0.0107, Test Loss: 0.0161, Test AUC: 0.7778, PR AUC: 0.8507, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0155
# ====> Epoch: 41 Average test Loss: 0.0113
# Fold 14 Results - Best Epoch: 41, Val Loss: 0.0155, Test Loss: 0.0113, Test AUC: 0.8472, PR AUC: 0.8709, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 65. Best Val Loss: 0.0080
# ====> Epoch: 65 Average test Loss: 0.0205
# Fold 15 Results - Best Epoch: 65, Val Loss: 0.0080, Test Loss: 0.0205, Test AUC: 0.7778, PR AUC: 0.8439, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 26. Best Val Loss: 0.0152
# ====> Epoch: 26 Average test Loss: 0.0217
# Fold 16 Results - Best Epoch: 26, Val Loss: 0.0152, Test Loss: 0.0217, Test AUC: 0.6806, PR AUC: 0.7278, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0161
# ====> Epoch: 37 Average test Loss: 0.0090
# Fold 17 Results - Best Epoch: 37, Val Loss: 0.0161, Test Loss: 0.0090, Test AUC: 0.9028, PR AUC: 0.9116, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 32. Best Val Loss: 0.0127
# ====> Epoch: 32 Average test Loss: 0.0134
# Fold 18 Results - Best Epoch: 32, Val Loss: 0.0127, Test Loss: 0.0134, Test AUC: 0.7083, PR AUC: 0.7538, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 31. Best Val Loss: 0.0134
# ====> Epoch: 31 Average test Loss: 0.0231
# Fold 19 Results - Best Epoch: 31, Val Loss: 0.0134, Test Loss: 0.0231, Test AUC: 0.6528, PR AUC: 0.7652, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 40. Best Val Loss: 0.0120
# ====> Epoch: 40 Average test Loss: 0.0310
# Fold 20 Results - Best Epoch: 40, Val Loss: 0.0120, Test Loss: 0.0310, Test AUC: 0.8472, PR AUC: 0.8606, Accuracy: 0.5294
#
# Combination 4 Results:
# Mean Test Loss: 0.0158 ± 0.0055
# Mean Test AUC: 0.7855 ± 0.0945
# Mean Test PR AUC: 0.8317 ± 0.0787
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 5/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 16, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0111
# ====> Epoch: 41 Average test Loss: 0.0123
# Fold 1 Results - Best Epoch: 41, Val Loss: 0.0111, Test Loss: 0.0123, Test AUC: 0.8250, PR AUC: 0.8764, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0090
# ====> Epoch: 46 Average test Loss: 0.0101
# Fold 2 Results - Best Epoch: 46, Val Loss: 0.0090, Test Loss: 0.0101, Test AUC: 0.8500, PR AUC: 0.9021, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 45. Best Val Loss: 0.0106
# ====> Epoch: 45 Average test Loss: 0.0137
# Fold 3 Results - Best Epoch: 45, Val Loss: 0.0106, Test Loss: 0.0137, Test AUC: 0.7750, PR AUC: 0.8688, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0126
# ====> Epoch: 43 Average test Loss: 0.0136
# Fold 4 Results - Best Epoch: 43, Val Loss: 0.0126, Test Loss: 0.0136, Test AUC: 0.6857, PR AUC: 0.7076, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 48. Best Val Loss: 0.0091
# ====> Epoch: 48 Average test Loss: 0.0089
# Fold 5 Results - Best Epoch: 48, Val Loss: 0.0091, Test Loss: 0.0089, Test AUC: 0.9143, PR AUC: 0.9263, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 62. Best Val Loss: 0.0044
# ====> Epoch: 62 Average test Loss: 0.0240
# Fold 6 Results - Best Epoch: 62, Val Loss: 0.0044, Test Loss: 0.0240, Test AUC: 0.7857, PR AUC: 0.8582, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 31. Best Val Loss: 0.0133
# ====> Epoch: 31 Average test Loss: 0.0159
# Fold 7 Results - Best Epoch: 31, Val Loss: 0.0133, Test Loss: 0.0159, Test AUC: 0.7917, PR AUC: 0.8000, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 31. Best Val Loss: 0.0129
# ====> Epoch: 31 Average test Loss: 0.0157
# Fold 8 Results - Best Epoch: 31, Val Loss: 0.0129, Test Loss: 0.0157, Test AUC: 0.5972, PR AUC: 0.6881, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 32. Best Val Loss: 0.0122
# ====> Epoch: 32 Average test Loss: 0.0160
# Fold 9 Results - Best Epoch: 32, Val Loss: 0.0122, Test Loss: 0.0160, Test AUC: 0.7361, PR AUC: 0.7967, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0141
# ====> Epoch: 39 Average test Loss: 0.0152
# Fold 10 Results - Best Epoch: 39, Val Loss: 0.0141, Test Loss: 0.0152, Test AUC: 0.7500, PR AUC: 0.8011, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 34. Best Val Loss: 0.0130
# ====> Epoch: 34 Average test Loss: 0.0124
# Fold 11 Results - Best Epoch: 34, Val Loss: 0.0130, Test Loss: 0.0124, Test AUC: 0.9167, PR AUC: 0.9278, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0135
# ====> Epoch: 39 Average test Loss: 0.0111
# Fold 12 Results - Best Epoch: 39, Val Loss: 0.0135, Test Loss: 0.0111, Test AUC: 0.9722, PR AUC: 0.9765, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 40. Best Val Loss: 0.0120
# ====> Epoch: 40 Average test Loss: 0.0161
# Fold 13 Results - Best Epoch: 40, Val Loss: 0.0120, Test Loss: 0.0161, Test AUC: 0.7778, PR AUC: 0.8481, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 59. Best Val Loss: 0.0115
# ====> Epoch: 59 Average test Loss: 0.0118
# Fold 14 Results - Best Epoch: 59, Val Loss: 0.0115, Test Loss: 0.0118, Test AUC: 0.8889, PR AUC: 0.9094, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0086
# ====> Epoch: 57 Average test Loss: 0.0220
# Fold 15 Results - Best Epoch: 57, Val Loss: 0.0086, Test Loss: 0.0220, Test AUC: 0.7500, PR AUC: 0.7579, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 19. Best Val Loss: 0.0150
# ====> Epoch: 19 Average test Loss: 0.0142
# Fold 16 Results - Best Epoch: 19, Val Loss: 0.0150, Test Loss: 0.0142, Test AUC: 0.8472, PR AUC: 0.8764, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0100
# ====> Epoch: 36 Average test Loss: 0.0115
# Fold 17 Results - Best Epoch: 36, Val Loss: 0.0100, Test Loss: 0.0115, Test AUC: 0.8333, PR AUC: 0.8568, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0144
# ====> Epoch: 27 Average test Loss: 0.0111
# Fold 18 Results - Best Epoch: 27, Val Loss: 0.0144, Test Loss: 0.0111, Test AUC: 0.8333, PR AUC: 0.8520, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0127
# ====> Epoch: 46 Average test Loss: 0.0295
# Fold 19 Results - Best Epoch: 46, Val Loss: 0.0127, Test Loss: 0.0295, Test AUC: 0.6250, PR AUC: 0.7395, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 28. Best Val Loss: 0.0113
# ====> Epoch: 28 Average test Loss: 0.0353
# Fold 20 Results - Best Epoch: 28, Val Loss: 0.0113, Test Loss: 0.0353, Test AUC: 0.8472, PR AUC: 0.8366, Accuracy: 0.5294
#
# Combination 5 Results:
# Mean Test Loss: 0.0160 ± 0.0066
# Mean Test AUC: 0.8001 ± 0.0920
# Mean Test PR AUC: 0.8403 ± 0.0739
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 6/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 16, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0136
# ====> Epoch: 38 Average test Loss: 0.0141
# Fold 1 Results - Best Epoch: 38, Val Loss: 0.0136, Test Loss: 0.0141, Test AUC: 0.7875, PR AUC: 0.7978, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 46. Best Val Loss: 0.0107
# ====> Epoch: 46 Average test Loss: 0.0117
# Fold 2 Results - Best Epoch: 46, Val Loss: 0.0107, Test Loss: 0.0117, Test AUC: 0.8000, PR AUC: 0.8427, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 55. Best Val Loss: 0.0110
# ====> Epoch: 55 Average test Loss: 0.0185
# Fold 3 Results - Best Epoch: 55, Val Loss: 0.0110, Test Loss: 0.0185, Test AUC: 0.7125, PR AUC: 0.7756, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 65. Best Val Loss: 0.0106
# ====> Epoch: 65 Average test Loss: 0.0126
# Fold 4 Results - Best Epoch: 65, Val Loss: 0.0106, Test Loss: 0.0126, Test AUC: 0.6571, PR AUC: 0.7724, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 28. Best Val Loss: 0.0141
# ====> Epoch: 28 Average test Loss: 0.0110
# Fold 5 Results - Best Epoch: 28, Val Loss: 0.0141, Test Loss: 0.0110, Test AUC: 1.0000, PR AUC: 1.0000, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0066
# ====> Epoch: 57 Average test Loss: 0.0146
# Fold 6 Results - Best Epoch: 57, Val Loss: 0.0066, Test Loss: 0.0146, Test AUC: 0.7857, PR AUC: 0.8737, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0153
# ====> Epoch: 41 Average test Loss: 0.0227
# Fold 7 Results - Best Epoch: 41, Val Loss: 0.0153, Test Loss: 0.0227, Test AUC: 0.7222, PR AUC: 0.7412, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0122
# ====> Epoch: 44 Average test Loss: 0.0183
# Fold 8 Results - Best Epoch: 44, Val Loss: 0.0122, Test Loss: 0.0183, Test AUC: 0.6111, PR AUC: 0.7122, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0120
# ====> Epoch: 38 Average test Loss: 0.0173
# Fold 9 Results - Best Epoch: 38, Val Loss: 0.0120, Test Loss: 0.0173, Test AUC: 0.7500, PR AUC: 0.8110, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 23. Best Val Loss: 0.0170
# ====> Epoch: 23 Average test Loss: 0.0157
# Fold 10 Results - Best Epoch: 23, Val Loss: 0.0170, Test Loss: 0.0157, Test AUC: 0.6528, PR AUC: 0.7275, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 42. Best Val Loss: 0.0132
# ====> Epoch: 42 Average test Loss: 0.0107
# Fold 11 Results - Best Epoch: 42, Val Loss: 0.0132, Test Loss: 0.0107, Test AUC: 0.8472, PR AUC: 0.9116, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0141
# ====> Epoch: 35 Average test Loss: 0.0087
# Fold 12 Results - Best Epoch: 35, Val Loss: 0.0141, Test Loss: 0.0087, Test AUC: 0.9167, PR AUC: 0.9361, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 56. Best Val Loss: 0.0110
# ====> Epoch: 56 Average test Loss: 0.0154
# Fold 13 Results - Best Epoch: 56, Val Loss: 0.0110, Test Loss: 0.0154, Test AUC: 0.7778, PR AUC: 0.8517, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 53. Best Val Loss: 0.0136
# ====> Epoch: 53 Average test Loss: 0.0110
# Fold 14 Results - Best Epoch: 53, Val Loss: 0.0136, Test Loss: 0.0110, Test AUC: 0.8750, PR AUC: 0.8830, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 48. Best Val Loss: 0.0091
# ====> Epoch: 48 Average test Loss: 0.0144
# Fold 15 Results - Best Epoch: 48, Val Loss: 0.0091, Test Loss: 0.0144, Test AUC: 0.8194, PR AUC: 0.8408, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 47. Best Val Loss: 0.0146
# ====> Epoch: 47 Average test Loss: 0.0184
# Fold 16 Results - Best Epoch: 47, Val Loss: 0.0146, Test Loss: 0.0184, Test AUC: 0.7778, PR AUC: 0.8137, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0139
# ====> Epoch: 44 Average test Loss: 0.0089
# Fold 17 Results - Best Epoch: 44, Val Loss: 0.0139, Test Loss: 0.0089, Test AUC: 0.9306, PR AUC: 0.9377, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 25. Best Val Loss: 0.0139
# ====> Epoch: 25 Average test Loss: 0.0138
# Fold 18 Results - Best Epoch: 25, Val Loss: 0.0139, Test Loss: 0.0138, Test AUC: 0.8333, PR AUC: 0.8594, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 50. Best Val Loss: 0.0114
# ====> Epoch: 50 Average test Loss: 0.0155
# Fold 19 Results - Best Epoch: 50, Val Loss: 0.0114, Test Loss: 0.0155, Test AUC: 0.7639, PR AUC: 0.8309, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0154
# ====> Epoch: 30 Average test Loss: 0.0264
# Fold 20 Results - Best Epoch: 30, Val Loss: 0.0154, Test Loss: 0.0264, Test AUC: 0.8194, PR AUC: 0.8513, Accuracy: 0.5294
#
# Combination 6 Results:
# Mean Test Loss: 0.0150 ± 0.0043
# Mean Test AUC: 0.7920 ± 0.0937
# Mean Test PR AUC: 0.8385 ± 0.0721
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 7/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 8, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 154. Best Val Loss: 0.0134
# ====> Epoch: 154 Average test Loss: 0.0121
# Fold 1 Results - Best Epoch: 154, Val Loss: 0.0134, Test Loss: 0.0121, Test AUC: 0.8500, PR AUC: 0.8899, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 156. Best Val Loss: 0.0100
# ====> Epoch: 156 Average test Loss: 0.0095
# Fold 2 Results - Best Epoch: 156, Val Loss: 0.0100, Test Loss: 0.0095, Test AUC: 0.8750, PR AUC: 0.9310, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 106. Best Val Loss: 0.0131
# ====> Epoch: 106 Average test Loss: 0.0153
# Fold 3 Results - Best Epoch: 106, Val Loss: 0.0131, Test Loss: 0.0153, Test AUC: 0.7375, PR AUC: 0.7797, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 107. Best Val Loss: 0.0129
# ====> Epoch: 107 Average test Loss: 0.0162
# Fold 4 Results - Best Epoch: 107, Val Loss: 0.0129, Test Loss: 0.0162, Test AUC: 0.7714, PR AUC: 0.8249, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 168. Best Val Loss: 0.0129
# ====> Epoch: 168 Average test Loss: 0.0141
# Fold 5 Results - Best Epoch: 168, Val Loss: 0.0129, Test Loss: 0.0141, Test AUC: 0.6714, PR AUC: 0.7707, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 186. Best Val Loss: 0.0090
# ====> Epoch: 186 Average test Loss: 0.0146
# Fold 6 Results - Best Epoch: 186, Val Loss: 0.0090, Test Loss: 0.0146, Test AUC: 0.8857, PR AUC: 0.9332, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 165. Best Val Loss: 0.0130
# ====> Epoch: 165 Average test Loss: 0.0195
# Fold 7 Results - Best Epoch: 165, Val Loss: 0.0130, Test Loss: 0.0195, Test AUC: 0.7778, PR AUC: 0.8164, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 96. Best Val Loss: 0.0128
# ====> Epoch: 96 Average test Loss: 0.0184
# Fold 8 Results - Best Epoch: 96, Val Loss: 0.0128, Test Loss: 0.0184, Test AUC: 0.6111, PR AUC: 0.7153, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 55. Best Val Loss: 0.0179
# ====> Epoch: 55 Average test Loss: 0.0193
# Fold 9 Results - Best Epoch: 55, Val Loss: 0.0179, Test Loss: 0.0193, Test AUC: 0.5694, PR AUC: 0.6918, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0171
# ====> Epoch: 18 Average test Loss: 0.0196
# Fold 10 Results - Best Epoch: 18, Val Loss: 0.0171, Test Loss: 0.0196, Test AUC: 0.5556, PR AUC: 0.5756, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 124. Best Val Loss: 0.0141
# ====> Epoch: 124 Average test Loss: 0.0113
# Fold 11 Results - Best Epoch: 124, Val Loss: 0.0141, Test Loss: 0.0113, Test AUC: 0.9028, PR AUC: 0.9202, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 90. Best Val Loss: 0.0148
# ====> Epoch: 90 Average test Loss: 0.0109
# Fold 12 Results - Best Epoch: 90, Val Loss: 0.0148, Test Loss: 0.0109, Test AUC: 0.9306, PR AUC: 0.9460, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 164. Best Val Loss: 0.0116
# ====> Epoch: 164 Average test Loss: 0.0117
# Fold 13 Results - Best Epoch: 164, Val Loss: 0.0116, Test Loss: 0.0117, Test AUC: 0.8194, PR AUC: 0.9050, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 124. Best Val Loss: 0.0122
# ====> Epoch: 124 Average test Loss: 0.0113
# Fold 14 Results - Best Epoch: 124, Val Loss: 0.0122, Test Loss: 0.0113, Test AUC: 0.9167, PR AUC: 0.9361, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 137. Best Val Loss: 0.0093
# ====> Epoch: 137 Average test Loss: 0.0139
# Fold 15 Results - Best Epoch: 137, Val Loss: 0.0093, Test Loss: 0.0139, Test AUC: 0.7778, PR AUC: 0.8389, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 104. Best Val Loss: 0.0158
# ====> Epoch: 104 Average test Loss: 0.0139
# Fold 16 Results - Best Epoch: 104, Val Loss: 0.0158, Test Loss: 0.0139, Test AUC: 0.8750, PR AUC: 0.9134, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 62. Best Val Loss: 0.0181
# ====> Epoch: 62 Average test Loss: 0.0153
# Fold 17 Results - Best Epoch: 62, Val Loss: 0.0181, Test Loss: 0.0153, Test AUC: 0.8472, PR AUC: 0.8908, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 101. Best Val Loss: 0.0149
# ====> Epoch: 101 Average test Loss: 0.0154
# Fold 18 Results - Best Epoch: 101, Val Loss: 0.0149, Test Loss: 0.0154, Test AUC: 0.7639, PR AUC: 0.7778, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 102. Best Val Loss: 0.0147
# ====> Epoch: 102 Average test Loss: 0.0179
# Fold 19 Results - Best Epoch: 102, Val Loss: 0.0147, Test Loss: 0.0179, Test AUC: 0.7639, PR AUC: 0.8402, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 136. Best Val Loss: 0.0103
# ====> Epoch: 136 Average test Loss: 0.0317
# Fold 20 Results - Best Epoch: 136, Val Loss: 0.0103, Test Loss: 0.0317, Test AUC: 0.9028, PR AUC: 0.9093, Accuracy: 0.5294
#
# Combination 7 Results:
# Mean Test Loss: 0.0156 ± 0.0048
# Mean Test AUC: 0.7902 ± 0.1111
# Mean Test PR AUC: 0.8403 ± 0.0959
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 8/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 8, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 108. Best Val Loss: 0.0149
# ====> Epoch: 108 Average test Loss: 0.0129
# Fold 1 Results - Best Epoch: 108, Val Loss: 0.0149, Test Loss: 0.0129, Test AUC: 0.8250, PR AUC: 0.8608, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 141. Best Val Loss: 0.0124
# ====> Epoch: 141 Average test Loss: 0.0109
# Fold 2 Results - Best Epoch: 141, Val Loss: 0.0124, Test Loss: 0.0109, Test AUC: 0.8500, PR AUC: 0.8860, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 136. Best Val Loss: 0.0119
# ====> Epoch: 136 Average test Loss: 0.0163
# Fold 3 Results - Best Epoch: 136, Val Loss: 0.0119, Test Loss: 0.0163, Test AUC: 0.7750, PR AUC: 0.7956, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 129. Best Val Loss: 0.0118
# ====> Epoch: 129 Average test Loss: 0.0129
# Fold 4 Results - Best Epoch: 129, Val Loss: 0.0118, Test Loss: 0.0129, Test AUC: 0.8143, PR AUC: 0.8861, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 197. Best Val Loss: 0.0123
# ====> Epoch: 197 Average test Loss: 0.0107
# Fold 5 Results - Best Epoch: 197, Val Loss: 0.0123, Test Loss: 0.0107, Test AUC: 0.8429, PR AUC: 0.8967, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0181
# ====> Epoch: 11 Average test Loss: 0.0192
# Fold 6 Results - Best Epoch: 11, Val Loss: 0.0181, Test Loss: 0.0192, Test AUC: 0.6571, PR AUC: 0.7903, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 145. Best Val Loss: 0.0144
# ====> Epoch: 145 Average test Loss: 0.0165
# Fold 7 Results - Best Epoch: 145, Val Loss: 0.0144, Test Loss: 0.0165, Test AUC: 0.7917, PR AUC: 0.8000, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 155. Best Val Loss: 0.0114
# ====> Epoch: 155 Average test Loss: 0.0158
# Fold 8 Results - Best Epoch: 155, Val Loss: 0.0114, Test Loss: 0.0158, Test AUC: 0.6528, PR AUC: 0.7272, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 126. Best Val Loss: 0.0131
# ====> Epoch: 126 Average test Loss: 0.0153
# Fold 9 Results - Best Epoch: 126, Val Loss: 0.0131, Test Loss: 0.0153, Test AUC: 0.7361, PR AUC: 0.7801, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 78. Best Val Loss: 0.0170
# ====> Epoch: 78 Average test Loss: 0.0132
# Fold 10 Results - Best Epoch: 78, Val Loss: 0.0170, Test Loss: 0.0132, Test AUC: 0.7917, PR AUC: 0.8090, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 178. Best Val Loss: 0.0113
# ====> Epoch: 178 Average test Loss: 0.0093
# Fold 11 Results - Best Epoch: 178, Val Loss: 0.0113, Test Loss: 0.0093, Test AUC: 0.8750, PR AUC: 0.9149, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 80. Best Val Loss: 0.0162
# ====> Epoch: 80 Average test Loss: 0.0132
# Fold 12 Results - Best Epoch: 80, Val Loss: 0.0162, Test Loss: 0.0132, Test AUC: 0.8611, PR AUC: 0.8687, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 153. Best Val Loss: 0.0127
# ====> Epoch: 153 Average test Loss: 0.0148
# Fold 13 Results - Best Epoch: 153, Val Loss: 0.0127, Test Loss: 0.0148, Test AUC: 0.7778, PR AUC: 0.8415, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 215. Best Val Loss: 0.0152
# ====> Epoch: 215 Average test Loss: 0.0141
# Fold 14 Results - Best Epoch: 215, Val Loss: 0.0152, Test Loss: 0.0141, Test AUC: 0.8750, PR AUC: 0.8616, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0178
# ====> Epoch: 14 Average test Loss: 0.0197
# Fold 15 Results - Best Epoch: 14, Val Loss: 0.0178, Test Loss: 0.0197, Test AUC: 0.4028, PR AUC: 0.5320, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 94. Best Val Loss: 0.0154
# ====> Epoch: 94 Average test Loss: 0.0140
# Fold 16 Results - Best Epoch: 94, Val Loss: 0.0154, Test Loss: 0.0140, Test AUC: 0.7361, PR AUC: 0.7587, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 64. Best Val Loss: 0.0179
# ====> Epoch: 64 Average test Loss: 0.0137
# Fold 17 Results - Best Epoch: 64, Val Loss: 0.0179, Test Loss: 0.0137, Test AUC: 0.8333, PR AUC: 0.8628, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 153. Best Val Loss: 0.0146
# ====> Epoch: 153 Average test Loss: 0.0104
# Fold 18 Results - Best Epoch: 153, Val Loss: 0.0146, Test Loss: 0.0104, Test AUC: 0.9722, PR AUC: 0.9765, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 113. Best Val Loss: 0.0158
# ====> Epoch: 113 Average test Loss: 0.0192
# Fold 19 Results - Best Epoch: 113, Val Loss: 0.0158, Test Loss: 0.0192, Test AUC: 0.6667, PR AUC: 0.7481, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 138. Best Val Loss: 0.0146
# ====> Epoch: 138 Average test Loss: 0.0362
# Fold 20 Results - Best Epoch: 138, Val Loss: 0.0146, Test Loss: 0.0362, Test AUC: 0.7222, PR AUC: 0.7510, Accuracy: 0.5294
#
# Combination 8 Results:
# Mean Test Loss: 0.0154 ± 0.0056
# Mean Test AUC: 0.7729 ± 0.1161
# Mean Test PR AUC: 0.8174 ± 0.0908
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 9/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 8, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 109. Best Val Loss: 0.0130
# ====> Epoch: 109 Average test Loss: 0.0148
# Fold 1 Results - Best Epoch: 109, Val Loss: 0.0130, Test Loss: 0.0148, Test AUC: 0.7125, PR AUC: 0.7889, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0190
# Fold 2 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0190, Test AUC: 0.6375, PR AUC: 0.7152, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0191
# Fold 3 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0191, Test AUC: 0.6375, PR AUC: 0.7538, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 123. Best Val Loss: 0.0141
# ====> Epoch: 123 Average test Loss: 0.0136
# Fold 4 Results - Best Epoch: 123, Val Loss: 0.0141, Test Loss: 0.0136, Test AUC: 0.7429, PR AUC: 0.7769, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 149. Best Val Loss: 0.0135
# ====> Epoch: 149 Average test Loss: 0.0127
# Fold 5 Results - Best Epoch: 149, Val Loss: 0.0135, Test Loss: 0.0127, Test AUC: 0.8000, PR AUC: 0.8844, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 128. Best Val Loss: 0.0122
# ====> Epoch: 128 Average test Loss: 0.0122
# Fold 6 Results - Best Epoch: 128, Val Loss: 0.0122, Test Loss: 0.0122, Test AUC: 0.8143, PR AUC: 0.8587, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 118. Best Val Loss: 0.0151
# ====> Epoch: 118 Average test Loss: 0.0195
# Fold 7 Results - Best Epoch: 118, Val Loss: 0.0151, Test Loss: 0.0195, Test AUC: 0.7778, PR AUC: 0.8164, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 232. Best Val Loss: 0.0105
# ====> Epoch: 232 Average test Loss: 0.0195
# Fold 8 Results - Best Epoch: 232, Val Loss: 0.0105, Test Loss: 0.0195, Test AUC: 0.5556, PR AUC: 0.6743, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 286. Best Val Loss: 0.0100
# ====> Epoch: 286 Average test Loss: 0.0136
# Fold 9 Results - Best Epoch: 286, Val Loss: 0.0100, Test Loss: 0.0136, Test AUC: 0.8056, PR AUC: 0.8841, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0172
# ====> Epoch: 18 Average test Loss: 0.0194
# Fold 10 Results - Best Epoch: 18, Val Loss: 0.0172, Test Loss: 0.0194, Test AUC: 0.4861, PR AUC: 0.5579, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 158. Best Val Loss: 0.0134
# ====> Epoch: 158 Average test Loss: 0.0100
# Fold 11 Results - Best Epoch: 158, Val Loss: 0.0134, Test Loss: 0.0100, Test AUC: 0.8750, PR AUC: 0.9194, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 126. Best Val Loss: 0.0152
# ====> Epoch: 126 Average test Loss: 0.0111
# Fold 12 Results - Best Epoch: 126, Val Loss: 0.0152, Test Loss: 0.0111, Test AUC: 0.8750, PR AUC: 0.9149, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 129. Best Val Loss: 0.0135
# ====> Epoch: 129 Average test Loss: 0.0141
# Fold 13 Results - Best Epoch: 129, Val Loss: 0.0135, Test Loss: 0.0141, Test AUC: 0.7500, PR AUC: 0.8503, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 97. Best Val Loss: 0.0160
# ====> Epoch: 97 Average test Loss: 0.0128
# Fold 14 Results - Best Epoch: 97, Val Loss: 0.0160, Test Loss: 0.0128, Test AUC: 0.9028, PR AUC: 0.9116, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 179. Best Val Loss: 0.0092
# ====> Epoch: 179 Average test Loss: 0.0162
# Fold 15 Results - Best Epoch: 179, Val Loss: 0.0092, Test Loss: 0.0162, Test AUC: 0.6250, PR AUC: 0.6783, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 108. Best Val Loss: 0.0154
# ====> Epoch: 108 Average test Loss: 0.0174
# Fold 16 Results - Best Epoch: 108, Val Loss: 0.0154, Test Loss: 0.0174, Test AUC: 0.7639, PR AUC: 0.7676, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0179
# ====> Epoch: 12 Average test Loss: 0.0196
# Fold 17 Results - Best Epoch: 12, Val Loss: 0.0179, Test Loss: 0.0196, Test AUC: 0.4028, PR AUC: 0.5669, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 82. Best Val Loss: 0.0170
# ====> Epoch: 82 Average test Loss: 0.0168
# Fold 18 Results - Best Epoch: 82, Val Loss: 0.0170, Test Loss: 0.0168, Test AUC: 0.6944, PR AUC: 0.7843, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 171. Best Val Loss: 0.0129
# ====> Epoch: 171 Average test Loss: 0.0234
# Fold 19 Results - Best Epoch: 171, Val Loss: 0.0129, Test Loss: 0.0234, Test AUC: 0.7361, PR AUC: 0.8028, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0180
# ====> Epoch: 12 Average test Loss: 0.0195
# Fold 20 Results - Best Epoch: 12, Val Loss: 0.0180, Test Loss: 0.0195, Test AUC: 0.4167, PR AUC: 0.5828, Accuracy: 0.5294
#
# Combination 9 Results:
# Mean Test Loss: 0.0162 ± 0.0035
# Mean Test AUC: 0.7006 ± 0.1416
# Mean Test PR AUC: 0.7745 ± 0.1117
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 10/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 116. Best Val Loss: 0.0131
# ====> Epoch: 116 Average test Loss: 0.0137
# Fold 1 Results - Best Epoch: 116, Val Loss: 0.0131, Test Loss: 0.0137, Test AUC: 0.8000, PR AUC: 0.8459, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 154. Best Val Loss: 0.0119
# ====> Epoch: 154 Average test Loss: 0.0124
# Fold 2 Results - Best Epoch: 154, Val Loss: 0.0119, Test Loss: 0.0124, Test AUC: 0.8125, PR AUC: 0.8662, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 87. Best Val Loss: 0.0149
# ====> Epoch: 87 Average test Loss: 0.0134
# Fold 3 Results - Best Epoch: 87, Val Loss: 0.0149, Test Loss: 0.0134, Test AUC: 0.7750, PR AUC: 0.8252, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 157. Best Val Loss: 0.0098
# ====> Epoch: 157 Average test Loss: 0.0136
# Fold 4 Results - Best Epoch: 157, Val Loss: 0.0098, Test Loss: 0.0136, Test AUC: 0.7571, PR AUC: 0.8327, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 162. Best Val Loss: 0.0114
# ====> Epoch: 162 Average test Loss: 0.0134
# Fold 5 Results - Best Epoch: 162, Val Loss: 0.0114, Test Loss: 0.0134, Test AUC: 0.6429, PR AUC: 0.7373, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 174. Best Val Loss: 0.0085
# ====> Epoch: 174 Average test Loss: 0.0163
# Fold 6 Results - Best Epoch: 174, Val Loss: 0.0085, Test Loss: 0.0163, Test AUC: 0.7571, PR AUC: 0.8305, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 93. Best Val Loss: 0.0144
# ====> Epoch: 93 Average test Loss: 0.0177
# Fold 7 Results - Best Epoch: 93, Val Loss: 0.0144, Test Loss: 0.0177, Test AUC: 0.7778, PR AUC: 0.7902, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 113. Best Val Loss: 0.0126
# ====> Epoch: 113 Average test Loss: 0.0161
# Fold 8 Results - Best Epoch: 113, Val Loss: 0.0126, Test Loss: 0.0161, Test AUC: 0.7361, PR AUC: 0.7832, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 21. Best Val Loss: 0.0178
# ====> Epoch: 21 Average test Loss: 0.0182
# Fold 9 Results - Best Epoch: 21, Val Loss: 0.0178, Test Loss: 0.0182, Test AUC: 0.4583, PR AUC: 0.5774, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 105. Best Val Loss: 0.0149
# ====> Epoch: 105 Average test Loss: 0.0143
# Fold 10 Results - Best Epoch: 105, Val Loss: 0.0149, Test Loss: 0.0143, Test AUC: 0.8056, PR AUC: 0.8077, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 98. Best Val Loss: 0.0130
# ====> Epoch: 98 Average test Loss: 0.0079
# Fold 11 Results - Best Epoch: 98, Val Loss: 0.0130, Test Loss: 0.0079, Test AUC: 0.9167, PR AUC: 0.9329, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 117. Best Val Loss: 0.0144
# ====> Epoch: 117 Average test Loss: 0.0109
# Fold 12 Results - Best Epoch: 117, Val Loss: 0.0144, Test Loss: 0.0109, Test AUC: 0.8611, PR AUC: 0.8949, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 134. Best Val Loss: 0.0115
# ====> Epoch: 134 Average test Loss: 0.0147
# Fold 13 Results - Best Epoch: 134, Val Loss: 0.0115, Test Loss: 0.0147, Test AUC: 0.7639, PR AUC: 0.8513, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 91. Best Val Loss: 0.0158
# ====> Epoch: 91 Average test Loss: 0.0144
# Fold 14 Results - Best Epoch: 91, Val Loss: 0.0158, Test Loss: 0.0144, Test AUC: 0.7917, PR AUC: 0.7723, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0181
# ====> Epoch: 18 Average test Loss: 0.0187
# Fold 15 Results - Best Epoch: 18, Val Loss: 0.0181, Test Loss: 0.0187, Test AUC: 0.4583, PR AUC: 0.6173, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0181
# ====> Epoch: 11 Average test Loss: 0.0194
# Fold 16 Results - Best Epoch: 11, Val Loss: 0.0181, Test Loss: 0.0194, Test AUC: 0.8056, PR AUC: 0.8693, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 13. Best Val Loss: 0.0184
# ====> Epoch: 13 Average test Loss: 0.0205
# Fold 17 Results - Best Epoch: 13, Val Loss: 0.0184, Test Loss: 0.0205, Test AUC: 0.4306, PR AUC: 0.6060, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 140. Best Val Loss: 0.0137
# ====> Epoch: 140 Average test Loss: 0.0122
# Fold 18 Results - Best Epoch: 140, Val Loss: 0.0137, Test Loss: 0.0122, Test AUC: 0.8194, PR AUC: 0.8475, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0180
# ====> Epoch: 18 Average test Loss: 0.0188
# Fold 19 Results - Best Epoch: 18, Val Loss: 0.0180, Test Loss: 0.0188, Test AUC: 0.4861, PR AUC: 0.5933, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 143. Best Val Loss: 0.0117
# ====> Epoch: 143 Average test Loss: 0.0472
# Fold 20 Results - Best Epoch: 143, Val Loss: 0.0117, Test Loss: 0.0472, Test AUC: 0.8750, PR AUC: 0.8593, Accuracy: 0.5294
#
# Combination 10 Results:
# Mean Test Loss: 0.0167 ± 0.0076
# Mean Test AUC: 0.7265 ± 0.1448
# Mean Test PR AUC: 0.7870 ± 0.1035
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 11/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 108. Best Val Loss: 0.0125
# ====> Epoch: 108 Average test Loss: 0.0126
# Fold 1 Results - Best Epoch: 108, Val Loss: 0.0125, Test Loss: 0.0126, Test AUC: 0.8125, PR AUC: 0.8408, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 210. Best Val Loss: 0.0102
# ====> Epoch: 210 Average test Loss: 0.0109
# Fold 2 Results - Best Epoch: 210, Val Loss: 0.0102, Test Loss: 0.0109, Test AUC: 0.8250, PR AUC: 0.8734, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 64. Best Val Loss: 0.0161
# ====> Epoch: 64 Average test Loss: 0.0159
# Fold 3 Results - Best Epoch: 64, Val Loss: 0.0161, Test Loss: 0.0159, Test AUC: 0.7375, PR AUC: 0.7973, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 158. Best Val Loss: 0.0112
# ====> Epoch: 158 Average test Loss: 0.0174
# Fold 4 Results - Best Epoch: 158, Val Loss: 0.0112, Test Loss: 0.0174, Test AUC: 0.5286, PR AUC: 0.6084, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 180. Best Val Loss: 0.0095
# ====> Epoch: 180 Average test Loss: 0.0081
# Fold 5 Results - Best Epoch: 180, Val Loss: 0.0095, Test Loss: 0.0081, Test AUC: 0.9286, PR AUC: 0.9430, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 124. Best Val Loss: 0.0117
# ====> Epoch: 124 Average test Loss: 0.0135
# Fold 6 Results - Best Epoch: 124, Val Loss: 0.0117, Test Loss: 0.0135, Test AUC: 0.7714, PR AUC: 0.8555, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 96. Best Val Loss: 0.0149
# ====> Epoch: 96 Average test Loss: 0.0218
# Fold 7 Results - Best Epoch: 96, Val Loss: 0.0149, Test Loss: 0.0218, Test AUC: 0.7222, PR AUC: 0.6943, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 118. Best Val Loss: 0.0137
# ====> Epoch: 118 Average test Loss: 0.0174
# Fold 8 Results - Best Epoch: 118, Val Loss: 0.0137, Test Loss: 0.0174, Test AUC: 0.6111, PR AUC: 0.6995, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 13. Best Val Loss: 0.0179
# ====> Epoch: 13 Average test Loss: 0.0183
# Fold 9 Results - Best Epoch: 13, Val Loss: 0.0179, Test Loss: 0.0183, Test AUC: 0.7500, PR AUC: 0.8553, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 140. Best Val Loss: 0.0142
# ====> Epoch: 140 Average test Loss: 0.0156
# Fold 10 Results - Best Epoch: 140, Val Loss: 0.0142, Test Loss: 0.0156, Test AUC: 0.7222, PR AUC: 0.7612, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 121. Best Val Loss: 0.0128
# ====> Epoch: 121 Average test Loss: 0.0088
# Fold 11 Results - Best Epoch: 121, Val Loss: 0.0128, Test Loss: 0.0088, Test AUC: 0.9167, PR AUC: 0.9419, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 90. Best Val Loss: 0.0136
# ====> Epoch: 90 Average test Loss: 0.0093
# Fold 12 Results - Best Epoch: 90, Val Loss: 0.0136, Test Loss: 0.0093, Test AUC: 0.9444, PR AUC: 0.9576, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 141. Best Val Loss: 0.0108
# ====> Epoch: 141 Average test Loss: 0.0147
# Fold 13 Results - Best Epoch: 141, Val Loss: 0.0108, Test Loss: 0.0147, Test AUC: 0.7361, PR AUC: 0.8356, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 95. Best Val Loss: 0.0137
# ====> Epoch: 95 Average test Loss: 0.0109
# Fold 14 Results - Best Epoch: 95, Val Loss: 0.0137, Test Loss: 0.0109, Test AUC: 0.9167, PR AUC: 0.9329, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 19. Best Val Loss: 0.0176
# ====> Epoch: 19 Average test Loss: 0.0187
# Fold 15 Results - Best Epoch: 19, Val Loss: 0.0176, Test Loss: 0.0187, Test AUC: 0.5556, PR AUC: 0.6127, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 127. Best Val Loss: 0.0151
# ====> Epoch: 127 Average test Loss: 0.0160
# Fold 16 Results - Best Epoch: 127, Val Loss: 0.0151, Test Loss: 0.0160, Test AUC: 0.9028, PR AUC: 0.8783, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0202
# Fold 17 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0202, Test AUC: 0.4444, PR AUC: 0.5598, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 85. Best Val Loss: 0.0142
# ====> Epoch: 85 Average test Loss: 0.0153
# Fold 18 Results - Best Epoch: 85, Val Loss: 0.0142, Test Loss: 0.0153, Test AUC: 0.7778, PR AUC: 0.8075, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 98. Best Val Loss: 0.0143
# ====> Epoch: 98 Average test Loss: 0.0215
# Fold 19 Results - Best Epoch: 98, Val Loss: 0.0143, Test Loss: 0.0215, Test AUC: 0.6667, PR AUC: 0.7552, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 149. Best Val Loss: 0.0118
# ====> Epoch: 149 Average test Loss: 0.0380
# Fold 20 Results - Best Epoch: 149, Val Loss: 0.0118, Test Loss: 0.0380, Test AUC: 0.8194, PR AUC: 0.8372, Accuracy: 0.5294
#
# Combination 11 Results:
# Mean Test Loss: 0.0162 ± 0.0064
# Mean Test AUC: 0.7545 ± 0.1364
# Mean Test PR AUC: 0.8024 ± 0.1139
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# ===== Evaluating Hyperparameter Combination 12/12 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 191. Best Val Loss: 0.0109
# ====> Epoch: 191 Average test Loss: 0.0124
# Fold 1 Results - Best Epoch: 191, Val Loss: 0.0109, Test Loss: 0.0124, Test AUC: 0.7875, PR AUC: 0.8342, Accuracy: 0.5556
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0179
# ====> Epoch: 11 Average test Loss: 0.0197
# Fold 2 Results - Best Epoch: 11, Val Loss: 0.0179, Test Loss: 0.0197, Test AUC: 0.6250, PR AUC: 0.6580, Accuracy: 0.5556
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 147. Best Val Loss: 0.0123
# ====> Epoch: 147 Average test Loss: 0.0181
# Fold 3 Results - Best Epoch: 147, Val Loss: 0.0123, Test Loss: 0.0181, Test AUC: 0.7125, PR AUC: 0.7756, Accuracy: 0.5556
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 225. Best Val Loss: 0.0101
# ====> Epoch: 225 Average test Loss: 0.0133
# Fold 4 Results - Best Epoch: 225, Val Loss: 0.0101, Test Loss: 0.0133, Test AUC: 0.7429, PR AUC: 0.8469, Accuracy: 0.5882
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 22. Best Val Loss: 0.0173
# ====> Epoch: 22 Average test Loss: 0.0189
# Fold 5 Results - Best Epoch: 22, Val Loss: 0.0173, Test Loss: 0.0189, Test AUC: 0.5143, PR AUC: 0.6294, Accuracy: 0.5882
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 221. Best Val Loss: 0.0065
# ====> Epoch: 221 Average test Loss: 0.0159
# Fold 6 Results - Best Epoch: 221, Val Loss: 0.0065, Test Loss: 0.0159, Test AUC: 0.7857, PR AUC: 0.8802, Accuracy: 0.5882
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 140. Best Val Loss: 0.0138
# ====> Epoch: 140 Average test Loss: 0.0163
# Fold 7 Results - Best Epoch: 140, Val Loss: 0.0138, Test Loss: 0.0163, Test AUC: 0.8056, PR AUC: 0.7856, Accuracy: 0.5294
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 22. Best Val Loss: 0.0179
# ====> Epoch: 22 Average test Loss: 0.0193
# Fold 8 Results - Best Epoch: 22, Val Loss: 0.0179, Test Loss: 0.0193, Test AUC: 0.4167, PR AUC: 0.5644, Accuracy: 0.5294
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 21. Best Val Loss: 0.0178
# ====> Epoch: 21 Average test Loss: 0.0187
# Fold 9 Results - Best Epoch: 21, Val Loss: 0.0178, Test Loss: 0.0187, Test AUC: 0.5833, PR AUC: 0.6245, Accuracy: 0.5294
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 80. Best Val Loss: 0.0165
# ====> Epoch: 80 Average test Loss: 0.0169
# Fold 10 Results - Best Epoch: 80, Val Loss: 0.0165, Test Loss: 0.0169, Test AUC: 0.7222, PR AUC: 0.7286, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 111. Best Val Loss: 0.0135
# ====> Epoch: 111 Average test Loss: 0.0101
# Fold 11 Results - Best Epoch: 111, Val Loss: 0.0135, Test Loss: 0.0101, Test AUC: 0.8750, PR AUC: 0.9194, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 109. Best Val Loss: 0.0160
# ====> Epoch: 109 Average test Loss: 0.0101
# Fold 12 Results - Best Epoch: 109, Val Loss: 0.0160, Test Loss: 0.0101, Test AUC: 0.9167, PR AUC: 0.9361, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 110. Best Val Loss: 0.0141
# ====> Epoch: 110 Average test Loss: 0.0131
# Fold 13 Results - Best Epoch: 110, Val Loss: 0.0141, Test Loss: 0.0131, Test AUC: 0.7222, PR AUC: 0.8297, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0205
# Fold 14 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0205, Test AUC: 0.4722, PR AUC: 0.5509, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 164. Best Val Loss: 0.0088
# ====> Epoch: 164 Average test Loss: 0.0152
# Fold 15 Results - Best Epoch: 164, Val Loss: 0.0088, Test Loss: 0.0152, Test AUC: 0.6944, PR AUC: 0.7519, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0183
# ====> Epoch: 11 Average test Loss: 0.0191
# Fold 16 Results - Best Epoch: 11, Val Loss: 0.0183, Test Loss: 0.0191, Test AUC: 0.3750, PR AUC: 0.5015, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 92. Best Val Loss: 0.0169
# ====> Epoch: 92 Average test Loss: 0.0106
# Fold 17 Results - Best Epoch: 92, Val Loss: 0.0169, Test Loss: 0.0106, Test AUC: 0.8611, PR AUC: 0.8949, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0173
# ====> Epoch: 14 Average test Loss: 0.0185
# Fold 18 Results - Best Epoch: 14, Val Loss: 0.0173, Test Loss: 0.0185, Test AUC: 0.3194, PR AUC: 0.5145, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 221. Best Val Loss: 0.0116
# ====> Epoch: 221 Average test Loss: 0.0189
# Fold 19 Results - Best Epoch: 221, Val Loss: 0.0116, Test Loss: 0.0189, Test AUC: 0.7222, PR AUC: 0.7829, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 171. Best Val Loss: 0.0127
# ====> Epoch: 171 Average test Loss: 0.0601
# Fold 20 Results - Best Epoch: 171, Val Loss: 0.0127, Test Loss: 0.0601, Test AUC: 0.8056, PR AUC: 0.7856, Accuracy: 0.5294
#
# Combination 12 Results:
# Mean Test Loss: 0.0183 ± 0.0101
# Mean Test AUC: 0.6730 ± 0.1682
# Mean Test PR AUC: 0.7397 ± 0.1336
# Mean Test Accuracy: 0.5422 ± 0.0214
#
# Grid search completed. Results saved to single sto grid_search_results.csv
