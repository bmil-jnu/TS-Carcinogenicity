# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow
import seaborn as sns
import pandas as pd

from tensorflow import keras

from rdkit import Chem
from rdkit import DataStructs
from rdkit.Chem import AllChem
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit.Chem import rdMolDescriptors

from sklearn import datasets, metrics
from sklearn.metrics import auc, roc_auc_score, roc_curve, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import StandardScaler


from scipy import interp
from tensorflow.keras.layers import Embedding, Dense 
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint



from tensorflow.keras import backend as K 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import initializers
# Out:
# 2025-06-25 13:12:28.805584: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-25 13:12:29.624929: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2025-06-25 13:12:29.624992: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2025-06-25 13:12:29.624997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit, GridSearchCV
from sklearn.metrics import accuracy_score, roc_auc_score, average_precision_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from rdkit import Chem
from rdkit.Chem import AllChem, QED, DataStructs
import joblib
import os

# XGBoost import
from xgboost import XGBClassifier
# 데이터 로드 및 전처리
df = pd.read_csv('/data/home/dbswn0814/2025JCM/data/single task/liv_data.csv')

def preprocess_dataframe(df):
    df_copy = df.copy()
    df_copy.reset_index(drop=True, inplace=True)
    mols, none_list = [], []
    for i in range(len(df_copy)):
        smiles = str(df_copy.loc[i, 'SMILES'])
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            try:
                Chem.SanitizeMol(mol)
                mols.append(mol)
            except:
                none_list.append(i)
                print(f'Index {i}: 유효하지 않은 SMILES, 제외')
        else:
            none_list.append(i)
            print(f'Index {i}: None SMILES, 제외')
    if none_list:
        df_copy.drop(none_list, inplace=True)
        df_copy.reset_index(drop=True, inplace=True)
    return df_copy, mols

# 전처리 실행
df_clean, mols = preprocess_dataframe(df)

# Morgan Fingerprint 생성
fps = [AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024) for mol in mols]
arr_list = []
for bit in fps:
    arr = np.zeros((1024,), dtype=np.int8)
    DataStructs.ConvertToNumpyArray(bit, arr)
    arr_list.append(arr)
x_fingerprint = np.array(arr_list, dtype=np.float32)

# QED 속성 계산 및 스케일링
qe_props = [QED.properties(mol) for mol in mols]
qe_df = pd.DataFrame(qe_props)
scaler = StandardScaler()
qe_scaled = scaler.fit_transform(qe_df)
qe_scaled_df = pd.DataFrame(qe_scaled, columns=qe_df.columns)

# 최종 Feature 결합
features = np.hstack((x_fingerprint, qe_scaled_df.values))
final_df = pd.concat([pd.DataFrame(features), df_clean['liv'].reset_index(drop=True)], axis=1)
final_df.dropna(inplace=True)

X = final_df.drop('liv', axis=1).values
y = final_df['liv'].values

# K-Fold 외부 검증 설정
n_splits = 20
outer_cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=0)

save_dir = './grid_search'
os.makedirs(save_dir, exist_ok=True)

fold = 1
for train_idx, test_idx in outer_cv.split(X, y):
    print(f'=== Fold {fold} ===')
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]
    
    # Test 데이터 저장
    test_data = {'features': torch.tensor(X_test), 'labels': torch.tensor(y_test)}
    test_save_path = os.path.join(save_dir, f'LR_test_fold{fold}.pt')
    torch.save(test_data, test_save_path)
    print(f'Test 데이터 저장됨: {test_save_path}')
    
    # Train/Validation 분리
    sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=0)
    for tr_idx, val_idx in sss.split(X_train, y_train):
        X_tr, X_val = X_train[tr_idx], X_train[val_idx]
        y_tr, y_val = y_train[tr_idx], y_train[val_idx]

    # Train/Val 데이터 저장
    train_save_path = os.path.join(save_dir, f'LR_train_fold{fold}.pt')
    torch.save({'features': torch.tensor(X_tr), 'labels': torch.tensor(y_tr)},
               train_save_path)
    
    print(f'Train 데이터 저장됨: {train_save_path}')
    
    val_save_path = os.path.join(save_dir, f'LR_val_fold{fold}.pt')
    torch.save({'features': torch.tensor(X_val), 'labels': torch.tensor(y_val)},
               val_save_path)
    print(f'Validation 데이터 저장됨: {val_save_path}')
    
    # 불균형 처리: scale_pos_weight 계산
    neg_count = np.sum(y_tr == 0)
    pos_count = np.sum(y_tr == 1)
    scale_pos_weight = neg_count / pos_count

    # Inner CV 및 Grid Search 설정 (XGBoost)
    inner_cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    param_grid = {
        'n_estimators': [100, 200],
        'max_depth': [3, 6],
        'subsample': [0.8, 1.0],
        'colsample_bytree': [0.8, 1.0]
    }
    base_model = XGBClassifier(
        objective='binary:logistic',
        use_label_encoder=False,
        eval_metric='auc',
        scale_pos_weight=scale_pos_weight,
        random_state=42
    )
    grid_search = GridSearchCV(
        base_model,
        param_grid,
        cv=inner_cv,
        scoring='roc_auc',
        n_jobs=-1
    )

    # 하이퍼파라미터 탐색
    grid_search.fit(X_tr, y_tr)
    best_model = grid_search.best_estimator_
    print('Best params:', grid_search.best_params_)

    # Validation 데이터에서 평가 (기존과 동일)
    y_val_pred = best_model.predict(X_val)
    y_val_proba = best_model.predict_proba(X_val)[:, 1]
    val_metrics = {
        'accuracy': accuracy_score(y_val, y_val_pred),
        'roc_auc': roc_auc_score(y_val, y_val_proba),
        'avg_precision': average_precision_score(y_val, y_val_proba),
        'precision': precision_score(y_val, y_val_pred),
        'recall': recall_score(y_val, y_val_pred),
        'f1': f1_score(y_val, y_val_pred)
    }
    print(f'Validation Metrics: {val_metrics}')
    joblib.dump(val_metrics, os.path.join(save_dir, f'XGB_val_metrics_fold{fold}.pkl'))

    # 최적 모델 저장
    model_path = os.path.join(save_dir, f'xgboost_grid_fold{fold}.pkl')
    joblib.dump(best_model, model_path)
    print(f'Fold {fold} 완료, 모델 저장: {model_path}\n')

    fold += 1

print('모든 fold 완료.')
# Out:
# === Fold 1 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold1.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold1.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold1.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.48484848484848486, 'roc_auc': 0.5735294117647058, 'avg_precision': 0.6801441691842406, 'precision': 0.5, 'recall': 0.5294117647058824, 'f1': 0.5142857142857143}
# Fold 1 완료, 모델 저장: ./grid_search/xgboost_grid_fold1.pkl
#
# === Fold 2 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold2.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold2.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold2.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5757575757575758, 'roc_auc': 0.613970588235294, 'avg_precision': 0.6998352666400285, 'precision': 0.5882352941176471, 'recall': 0.5882352941176471, 'f1': 0.5882352941176471}
# Fold 2 완료, 모델 저장: ./grid_search/xgboost_grid_fold2.pkl
#
# === Fold 3 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold3.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold3.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold3.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5757575757575758, 'roc_auc': 0.6544117647058824, 'avg_precision': 0.7245004616505122, 'precision': 0.6, 'recall': 0.5294117647058824, 'f1': 0.5625}
# Fold 3 완료, 모델 저장: ./grid_search/xgboost_grid_fold3.pkl
#
# === Fold 4 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold4.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold4.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold4.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.6363636363636364, 'roc_auc': 0.6801470588235294, 'avg_precision': 0.6928461559452725, 'precision': 0.6923076923076923, 'recall': 0.5294117647058824, 'f1': 0.5999999999999999}
# Fold 4 완료, 모델 저장: ./grid_search/xgboost_grid_fold4.pkl
#
# === Fold 5 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold5.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold5.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold5.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.7272727272727273, 'roc_auc': 0.7352941176470589, 'avg_precision': 0.7950269064079806, 'precision': 0.75, 'recall': 0.7058823529411765, 'f1': 0.7272727272727272}
# Fold 5 완료, 모델 저장: ./grid_search/xgboost_grid_fold5.pkl
#
# === Fold 6 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold6.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold6.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold6.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.5151515151515151, 'roc_auc': 0.6323529411764706, 'avg_precision': 0.6082564763649028, 'precision': 0.5333333333333333, 'recall': 0.47058823529411764, 'f1': 0.5}
# Fold 6 완료, 모델 저장: ./grid_search/xgboost_grid_fold6.pkl
#
# === Fold 7 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold7.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold7.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold7.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.696969696969697, 'roc_auc': 0.75, 'avg_precision': 0.763120990889157, 'precision': 0.7058823529411765, 'recall': 0.7058823529411765, 'f1': 0.7058823529411765}
# Fold 7 완료, 모델 저장: ./grid_search/xgboost_grid_fold7.pkl
#
# === Fold 8 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold8.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold8.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold8.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.6060606060606061, 'roc_auc': 0.6544117647058824, 'avg_precision': 0.6705990650852899, 'precision': 0.6111111111111112, 'recall': 0.6470588235294118, 'f1': 0.6285714285714287}
# Fold 8 완료, 모델 저장: ./grid_search/xgboost_grid_fold8.pkl
#
# === Fold 9 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold9.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold9.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold9.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.5454545454545454, 'roc_auc': 0.599264705882353, 'avg_precision': 0.650040577222323, 'precision': 0.55, 'recall': 0.6470588235294118, 'f1': 0.5945945945945946}
# Fold 9 완료, 모델 저장: ./grid_search/xgboost_grid_fold9.pkl
#
# === Fold 10 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold10.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold10.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold10.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5454545454545454, 'roc_auc': 0.5441176470588235, 'avg_precision': 0.6109763260734857, 'precision': 0.5625, 'recall': 0.5294117647058824, 'f1': 0.5454545454545455}
# Fold 10 완료, 모델 저장: ./grid_search/xgboost_grid_fold10.pkl
#
# === Fold 11 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold11.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold11.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold11.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.45454545454545453, 'roc_auc': 0.47058823529411764, 'avg_precision': 0.49223123834345184, 'precision': 0.4666666666666667, 'recall': 0.4117647058823529, 'f1': 0.43749999999999994}
# Fold 11 완료, 모델 저장: ./grid_search/xgboost_grid_fold11.pkl
#
# === Fold 12 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold12.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold12.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold12.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5151515151515151, 'roc_auc': 0.6029411764705882, 'avg_precision': 0.589764047272876, 'precision': 0.5333333333333333, 'recall': 0.47058823529411764, 'f1': 0.5}
# Fold 12 완료, 모델 저장: ./grid_search/xgboost_grid_fold12.pkl
#
# === Fold 13 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold13.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold13.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold13.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 6, 'n_estimators': 200, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5454545454545454, 'roc_auc': 0.5220588235294118, 'avg_precision': 0.5973382958889301, 'precision': 0.5625, 'recall': 0.5294117647058824, 'f1': 0.5454545454545455}
# Fold 13 완료, 모델 저장: ./grid_search/xgboost_grid_fold13.pkl
#
# === Fold 14 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold14.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold14.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold14.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5151515151515151, 'roc_auc': 0.6213235294117647, 'avg_precision': 0.699710150613726, 'precision': 0.5333333333333333, 'recall': 0.47058823529411764, 'f1': 0.5}
# Fold 14 완료, 모델 저장: ./grid_search/xgboost_grid_fold14.pkl
#
# === Fold 15 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold15.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold15.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold15.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.48484848484848486, 'roc_auc': 0.5110294117647058, 'avg_precision': 0.5656564200616031, 'precision': 0.5, 'recall': 0.5294117647058824, 'f1': 0.5142857142857143}
# Fold 15 완료, 모델 저장: ./grid_search/xgboost_grid_fold15.pkl
#
# === Fold 16 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold16.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold16.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold16.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.5454545454545454, 'roc_auc': 0.5919117647058824, 'avg_precision': 0.6192559689306342, 'precision': 0.5555555555555556, 'recall': 0.5882352941176471, 'f1': 0.5714285714285715}
# Fold 16 완료, 모델 저장: ./grid_search/xgboost_grid_fold16.pkl
#
# === Fold 17 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold17.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold17.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold17.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.42424242424242425, 'roc_auc': 0.5073529411764706, 'avg_precision': 0.5334990022473005, 'precision': 0.4375, 'recall': 0.4117647058823529, 'f1': 0.42424242424242425}
# Fold 17 완료, 모델 저장: ./grid_search/xgboost_grid_fold17.pkl
#
# === Fold 18 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold18.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold18.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold18.pt
# Best params: {'colsample_bytree': 0.8, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.5151515151515151, 'roc_auc': 0.5992647058823529, 'avg_precision': 0.6279500463709228, 'precision': 0.5333333333333333, 'recall': 0.47058823529411764, 'f1': 0.5}
# Fold 18 완료, 모델 저장: ./grid_search/xgboost_grid_fold18.pkl
#
# === Fold 19 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold19.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold19.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold19.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
# Validation Metrics: {'accuracy': 0.45454545454545453, 'roc_auc': 0.5147058823529411, 'avg_precision': 0.6432757418146797, 'precision': 0.4666666666666667, 'recall': 0.4117647058823529, 'f1': 0.43749999999999994}
# Fold 19 완료, 모델 저장: ./grid_search/xgboost_grid_fold19.pkl
#
# === Fold 20 ===
# Test 데이터 저장됨: ./grid_search/LR_test_fold20.pt
# Train 데이터 저장됨: ./grid_search/LR_train_fold20.pt
# Validation 데이터 저장됨: ./grid_search/LR_val_fold20.pt
# Best params: {'colsample_bytree': 1.0, 'max_depth': 6, 'n_estimators': 100, 'subsample': 0.8}
# Validation Metrics: {'accuracy': 0.5454545454545454, 'roc_auc': 0.6139705882352942, 'avg_precision': 0.6249127659967831, 'precision': 0.5625, 'recall': 0.5294117647058824, 'f1': 0.5454545454545455}
# Fold 20 완료, 모델 저장: ./grid_search/xgboost_grid_fold20.pkl
#
# 모든 fold 완료.
