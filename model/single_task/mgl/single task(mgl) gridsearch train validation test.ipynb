# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import random
import time
from math import sqrt
import sklearn
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import (matthews_corrcoef, accuracy_score, confusion_matrix, 
                             roc_auc_score, average_precision_score, 
                             cohen_kappa_score, balanced_accuracy_score, 
                             roc_curve, auc, precision_recall_curve)
from bayes_opt import BayesianOptimization
from utils import (
    single_task, EarlyStopping, train_single_task, val_single_task, test_single_task,
    FocalLoss, load_data, CustomDataset)
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import Tensor
from torch.utils.data import TensorDataset,Subset, DataLoader, Dataset as TorchDataset  # 일반적인 PyTorch의 Dataset 사용
from torch_geometric.data import InMemoryDataset, DataLoader, Batch, Dataset, Data, data
from collections import defaultdict
torch.use_deterministic_algorithms(True, warn_only=True)
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit, ParameterGrid
import pandas as pd
import matplotlib.pyplot as plt  # 시각화를 위해 matplotlib도 필요합니다.
import warnings
warnings.filterwarnings("ignore")

# %%
def set_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    # 시드 고정
    torch.manual_seed(seed)  # PyTorch 난수 시드
    torch.cuda.manual_seed(seed)  # CUDA 난수 시드
    torch.cuda.manual_seed_all(seed)  # 멀티 GPU 사용 시 시드 고정
    
    # CuDNN을 결정적 모드로 설정
    torch.backends.cudnn.enabled = False
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    # Numpy 및 파이썬 기본 random 모듈의 시드 고정
    np.random.seed(seed)
    random.seed(seed)
    

# 시드 고정 호출
set_seed(2)

def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)
    
rng = np.random.default_rng(8888)
rfloat = rng.random()

# %%
def evaluate_model(model, device, data_loader):
    model.eval()
    y_true = []
    y_scores = []
    
    with torch.no_grad():
        for batch in data_loader:
            data = batch.to(device)
            labels = batch.y.to(device)
            outputs, _ = model(data)
            outputs = outputs.view_as(labels)
            probs = torch.sigmoid(outputs).cpu().numpy()
            y_scores.extend(probs.flatten())
            y_true.extend(labels.cpu().numpy().flatten())
    
    y_true = np.array(y_true)
    y_scores = np.array(y_scores)
    
    # -1 라벨 제거
    mask = y_true != -1
    y_true = y_true[mask]
    y_scores = y_scores[mask]
    
    try:
        auc = roc_auc_score(y_true, y_scores)
    except ValueError:
        auc = np.nan  # AUC를 계산할 수 없는 경우

    try:
        pr_auc = average_precision_score(y_true, y_scores)
    except ValueError:
        pr_auc = np.nan  # PR AUC를 계산할 수 없는 경우

    y_pred_labels = (y_scores >= 0.5).astype(int)
    accuracy = accuracy_score(y_true, y_pred_labels)
    
    return auc, pr_auc, accuracy

# %%
def main():
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    K = 20  # Number of folds
    
    # Define the hyperparameter grid
    param_grid = {
        'output_dim': [8, 16],
        'dropout': [0.2],
        'batch_size': [8, 16],
        'lr': [0.001, 0.0001],
        'wd': [1e-06, 1e-05, 1e-04],
    }
    
    grid = list(ParameterGrid(param_grid))
    total_combinations = len(grid)
    print(f"Total hyperparameter combinations to evaluate: {total_combinations}")
    
    # Load the dataset once
    dataset = load_data("mgl")
    X = dataset.data_x
    y = dataset.data_y
    
    # Initialize K-Fold
    kf = StratifiedKFold(n_splits=K, shuffle=True, random_state=1)
    
    # Prepare to store all results
    all_results = []
    
    # Iterate over each hyperparameter combination
    for idx, params in enumerate(grid, 1):
        print(f"\n===== Evaluating Hyperparameter Combination {idx}/{total_combinations} =====")
        print(f"Parameters: {params}")
        
        # To store results for all folds for the current hyperparameter combination
        fold_results = []
        
        for fold, (train_indices, test_indices) in enumerate(kf.split(X, y), 1):
            print(f"\n--- Fold {fold}/{K} ---")
            
            # Stratified Shuffle Split for validation set
            sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=1)
            train_idx, val_idx = next(sss.split(np.zeros(len(train_indices)), y[train_indices]))
            
            # Subset datasets
            train_subset = Subset(dataset, train_indices[train_idx])
            val_subset = Subset(dataset, train_indices[val_idx])
            test_subset = Subset(dataset, test_indices)
            
            # DataLoaders
            batch_size = params['batch_size']
            train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True, collate_fn=Batch.from_data_list)
            val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False, collate_fn=Batch.from_data_list)
            test_loader = DataLoader(test_subset, batch_size=batch_size, shuffle=False, collate_fn=Batch.from_data_list)
            
            # Initialize the model with current hyperparameters
            model = single_task(
                num_features=75, 
                n_heads1=2, 
                output_dim=params['output_dim'],
                dropout=params['dropout']
            ).to(device)
            
            # Define Loss and Optimizer with current hyperparameters
            criterion = FocalLoss(alpha=0.25, gamma=4.0, reduction='mean')
            optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'], weight_decay=params['wd'])
            
            # EarlyStopping setup
            checkpoint_path = f'/data/home/dbswn0814/2025JCM/model/single task/mgl/weight/checkpoint_combination_{idx}_fold_{fold}.pt'
            early_stopping = EarlyStopping(patience=10, verbose=False, path=checkpoint_path, trace_func=lambda x: None)
            
            # Training Loop
            num_epochs = 1000
            best_epoch = 0
            for epoch in range(1, num_epochs + 1):
                train_loss = train_single_task(epoch, model, criterion, optimizer, device, train_loader)
                val_loss = val_single_task(epoch, model, criterion, device, val_loader)
    
#                 print(f"Epoch {epoch}/{num_epochs} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")
    
                # Early Stopping
                early_stopping(val_loss, model)
    
                if early_stopping.early_stop:
                    print(f"Early stopping triggered at epoch {epoch}. Best Val Loss: {early_stopping.val_loss_min:.4f}")
                    best_epoch = epoch
                    break
                best_epoch = epoch  # Update best epoch
    
            # Load the best model
            model.load_state_dict(torch.load(checkpoint_path))
            
            # Evaluate on Test Set
            test_loss = test_single_task(epoch, model, criterion, device, test_loader)
            test_auc, test_pr_auc, test_accuracy = evaluate_model(model, device, test_loader)
            
            print(f"Fold {fold} Results - Best Epoch: {best_epoch}, Val Loss: {early_stopping.val_loss_min:.4f}, Test Loss: {test_loss:.4f}, Test AUC: {test_auc:.4f}, PR AUC: {test_pr_auc:.4f}, Accuracy: {test_accuracy:.4f}")
            
            # Store fold results
            fold_result = {
                'Combination': idx,
                'Fold': fold,
                'Best_Epoch': best_epoch,
                'Best_Val_Loss': early_stopping.val_loss_min,
                'Test_Loss': test_loss,
                'Test_AUC': test_auc,
                'Test_PR_AUC': test_pr_auc,
                'Test_Accuracy': test_accuracy
            }
            fold_results.append(fold_result)
        
        # After all folds, compute average and std metrics
        test_losses = [fr['Test_Loss'] for fr in fold_results]
        test_aucs = [fr['Test_AUC'] for fr in fold_results]
        test_pr_aucs = [fr['Test_PR_AUC'] for fr in fold_results]
        test_accuracies = [fr['Test_Accuracy'] for fr in fold_results]
        
        mean_test_loss = np.mean(test_losses)
        std_test_loss = np.std(test_losses)
        mean_test_auc = np.mean(test_aucs)
        std_test_auc = np.std(test_aucs)
        mean_test_pr_auc = np.mean(test_pr_aucs)
        std_test_pr_auc = np.std(test_pr_aucs)
        mean_test_accuracy = np.mean(test_accuracies)
        std_test_accuracy = np.std(test_accuracies)
        
        # Append the overall results for the current combination
        combination_result = {
            'Combination': idx,
            **params,
            'Mean_Test_Loss': mean_test_loss,
            'Std_Test_Loss': std_test_loss,
            'Mean_Test_AUC': mean_test_auc,
            'Std_Test_AUC': std_test_auc,
            'Mean_Test_PR_AUC': mean_test_pr_auc,
            'Std_Test_PR_AUC': std_test_pr_auc,
            'Mean_Test_Accuracy': mean_test_accuracy,
            'Std_Test_Accuracy': std_test_accuracy
        }
        all_results.append(combination_result)
        
        # Optionally, print the results for the current combination
        print(f"\nCombination {idx} Results:")
        print(f"Mean Test Loss: {mean_test_loss:.4f} ± {std_test_loss:.4f}")
        print(f"Mean Test AUC: {mean_test_auc:.4f} ± {std_test_auc:.4f}")
        print(f"Mean Test PR AUC: {mean_test_pr_auc:.4f} ± {std_test_pr_auc:.4f}")
        print(f"Mean Test Accuracy: {mean_test_accuracy:.4f} ± {std_test_accuracy:.4f}")
    
    # After all combinations, save results to CSV
    results_df = pd.DataFrame(all_results)
    results_csv_path = 'single mgl grid_search_results.csv'
    results_df.to_csv(results_csv_path, index=False)
    print(f"\nGrid search completed. Results saved to {results_csv_path}")
    
    # Optionally, visualize the results
    # Example: Plot Mean Test AUC for each combination
    plt.figure(figsize=(12, 6))
    plt.bar(range(len(all_results)), results_df['Mean_Test_AUC'], yerr=results_df['Std_Test_AUC'], capsize=5)
    plt.xlabel('Hyperparameter Combination')
    plt.ylabel('Mean Test AUC')
    plt.title('Grid Search: Mean Test AUC for Each Hyperparameter Combination')
    plt.xticks(range(len(all_results)), results_df['Combination'], rotation=90)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Total hyperparameter combinations to evaluate: 24
#
# ===== Evaluating Hyperparameter Combination 1/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 8, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 40. Best Val Loss: 0.0127
# ====> Epoch: 40 Average test Loss: 0.0192
# Fold 1 Results - Best Epoch: 40, Val Loss: 0.0127, Test Loss: 0.0192, Test AUC: 0.6049, PR AUC: 0.6690, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 55. Best Val Loss: 0.0100
# ====> Epoch: 55 Average test Loss: 0.0178
# Fold 2 Results - Best Epoch: 55, Val Loss: 0.0100, Test Loss: 0.0178, Test AUC: 0.6481, PR AUC: 0.7097, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0147
# ====> Epoch: 36 Average test Loss: 0.0197
# Fold 3 Results - Best Epoch: 36, Val Loss: 0.0147, Test Loss: 0.0197, Test AUC: 0.6667, PR AUC: 0.7668, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 71. Best Val Loss: 0.0096
# ====> Epoch: 71 Average test Loss: 0.0145
# Fold 4 Results - Best Epoch: 71, Val Loss: 0.0096, Test Loss: 0.0145, Test AUC: 0.6806, PR AUC: 0.6348, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0112
# ====> Epoch: 57 Average test Loss: 0.0137
# Fold 5 Results - Best Epoch: 57, Val Loss: 0.0112, Test Loss: 0.0137, Test AUC: 0.6944, PR AUC: 0.7339, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 55. Best Val Loss: 0.0126
# ====> Epoch: 55 Average test Loss: 0.0135
# Fold 6 Results - Best Epoch: 55, Val Loss: 0.0126, Test Loss: 0.0135, Test AUC: 0.7778, PR AUC: 0.7728, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 55. Best Val Loss: 0.0115
# ====> Epoch: 55 Average test Loss: 0.0101
# Fold 7 Results - Best Epoch: 55, Val Loss: 0.0115, Test Loss: 0.0101, Test AUC: 0.9722, PR AUC: 0.9750, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0131
# ====> Epoch: 30 Average test Loss: 0.0162
# Fold 8 Results - Best Epoch: 30, Val Loss: 0.0131, Test Loss: 0.0162, Test AUC: 0.8194, PR AUC: 0.8840, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0133
# ====> Epoch: 30 Average test Loss: 0.0150
# Fold 9 Results - Best Epoch: 30, Val Loss: 0.0133, Test Loss: 0.0150, Test AUC: 0.7917, PR AUC: 0.8400, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0133
# ====> Epoch: 35 Average test Loss: 0.0189
# Fold 10 Results - Best Epoch: 35, Val Loss: 0.0133, Test Loss: 0.0189, Test AUC: 0.4306, PR AUC: 0.4978, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0143
# ====> Epoch: 27 Average test Loss: 0.0155
# Fold 11 Results - Best Epoch: 27, Val Loss: 0.0143, Test Loss: 0.0155, Test AUC: 0.5556, PR AUC: 0.5436, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0132
# ====> Epoch: 36 Average test Loss: 0.0241
# Fold 12 Results - Best Epoch: 36, Val Loss: 0.0132, Test Loss: 0.0241, Test AUC: 0.4375, PR AUC: 0.5694, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 34. Best Val Loss: 0.0154
# ====> Epoch: 34 Average test Loss: 0.0163
# Fold 13 Results - Best Epoch: 34, Val Loss: 0.0154, Test Loss: 0.0163, Test AUC: 0.8056, PR AUC: 0.7894, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 54. Best Val Loss: 0.0125
# ====> Epoch: 54 Average test Loss: 0.0150
# Fold 14 Results - Best Epoch: 54, Val Loss: 0.0125, Test Loss: 0.0150, Test AUC: 0.7500, PR AUC: 0.7607, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0158
# ====> Epoch: 38 Average test Loss: 0.0153
# Fold 15 Results - Best Epoch: 38, Val Loss: 0.0158, Test Loss: 0.0153, Test AUC: 0.7917, PR AUC: 0.7736, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0129
# ====> Epoch: 36 Average test Loss: 0.0106
# Fold 16 Results - Best Epoch: 36, Val Loss: 0.0129, Test Loss: 0.0106, Test AUC: 0.8472, PR AUC: 0.8409, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0111
# ====> Epoch: 44 Average test Loss: 0.0197
# Fold 17 Results - Best Epoch: 44, Val Loss: 0.0111, Test Loss: 0.0197, Test AUC: 0.9167, PR AUC: 0.9361, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 58. Best Val Loss: 0.0128
# ====> Epoch: 58 Average test Loss: 0.0095
# Fold 18 Results - Best Epoch: 58, Val Loss: 0.0128, Test Loss: 0.0095, Test AUC: 0.9028, PR AUC: 0.8583, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0128
# ====> Epoch: 39 Average test Loss: 0.0174
# Fold 19 Results - Best Epoch: 39, Val Loss: 0.0128, Test Loss: 0.0174, Test AUC: 0.7778, PR AUC: 0.8716, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0140
# ====> Epoch: 43 Average test Loss: 0.0146
# Fold 20 Results - Best Epoch: 43, Val Loss: 0.0140, Test Loss: 0.0146, Test AUC: 0.7917, PR AUC: 0.7812, Accuracy: 0.5294
#
# Combination 1 Results:
# Mean Test Loss: 0.0158 ± 0.0035
# Mean Test AUC: 0.7331 ± 0.1419
# Mean Test PR AUC: 0.7604 ± 0.1242
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 2/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 8, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 24. Best Val Loss: 0.0148
# ====> Epoch: 24 Average test Loss: 0.0153
# Fold 1 Results - Best Epoch: 24, Val Loss: 0.0148, Test Loss: 0.0153, Test AUC: 0.6667, PR AUC: 0.6975, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 67. Best Val Loss: 0.0107
# ====> Epoch: 67 Average test Loss: 0.0184
# Fold 2 Results - Best Epoch: 67, Val Loss: 0.0107, Test Loss: 0.0184, Test AUC: 0.6049, PR AUC: 0.6783, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 34. Best Val Loss: 0.0149
# ====> Epoch: 34 Average test Loss: 0.0203
# Fold 3 Results - Best Epoch: 34, Val Loss: 0.0149, Test Loss: 0.0203, Test AUC: 0.5988, PR AUC: 0.6668, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0129
# ====> Epoch: 57 Average test Loss: 0.0127
# Fold 4 Results - Best Epoch: 57, Val Loss: 0.0129, Test Loss: 0.0127, Test AUC: 0.8750, PR AUC: 0.8785, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 45. Best Val Loss: 0.0119
# ====> Epoch: 45 Average test Loss: 0.0128
# Fold 5 Results - Best Epoch: 45, Val Loss: 0.0119, Test Loss: 0.0128, Test AUC: 0.7292, PR AUC: 0.6285, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 29. Best Val Loss: 0.0127
# ====> Epoch: 29 Average test Loss: 0.0124
# Fold 6 Results - Best Epoch: 29, Val Loss: 0.0127, Test Loss: 0.0124, Test AUC: 0.8472, PR AUC: 0.8608, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 51. Best Val Loss: 0.0099
# ====> Epoch: 51 Average test Loss: 0.0073
# Fold 7 Results - Best Epoch: 51, Val Loss: 0.0099, Test Loss: 0.0073, Test AUC: 0.9722, PR AUC: 0.9750, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0115
# ====> Epoch: 30 Average test Loss: 0.0198
# Fold 8 Results - Best Epoch: 30, Val Loss: 0.0115, Test Loss: 0.0198, Test AUC: 0.7361, PR AUC: 0.8063, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 25. Best Val Loss: 0.0138
# ====> Epoch: 25 Average test Loss: 0.0155
# Fold 9 Results - Best Epoch: 25, Val Loss: 0.0138, Test Loss: 0.0155, Test AUC: 0.7639, PR AUC: 0.7906, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 58. Best Val Loss: 0.0139
# ====> Epoch: 58 Average test Loss: 0.0196
# Fold 10 Results - Best Epoch: 58, Val Loss: 0.0139, Test Loss: 0.0196, Test AUC: 0.3750, PR AUC: 0.4536, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 48. Best Val Loss: 0.0112
# ====> Epoch: 48 Average test Loss: 0.0219
# Fold 11 Results - Best Epoch: 48, Val Loss: 0.0112, Test Loss: 0.0219, Test AUC: 0.5417, PR AUC: 0.5426, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0125
# ====> Epoch: 44 Average test Loss: 0.0257
# Fold 12 Results - Best Epoch: 44, Val Loss: 0.0125, Test Loss: 0.0257, Test AUC: 0.5486, PR AUC: 0.6415, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 33. Best Val Loss: 0.0164
# ====> Epoch: 33 Average test Loss: 0.0145
# Fold 13 Results - Best Epoch: 33, Val Loss: 0.0164, Test Loss: 0.0145, Test AUC: 0.8194, PR AUC: 0.8642, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 33. Best Val Loss: 0.0135
# ====> Epoch: 33 Average test Loss: 0.0145
# Fold 14 Results - Best Epoch: 33, Val Loss: 0.0135, Test Loss: 0.0145, Test AUC: 0.6806, PR AUC: 0.6991, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 49. Best Val Loss: 0.0123
# ====> Epoch: 49 Average test Loss: 0.0145
# Fold 15 Results - Best Epoch: 49, Val Loss: 0.0123, Test Loss: 0.0145, Test AUC: 0.7361, PR AUC: 0.6917, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0115
# ====> Epoch: 39 Average test Loss: 0.0166
# Fold 16 Results - Best Epoch: 39, Val Loss: 0.0115, Test Loss: 0.0166, Test AUC: 0.8056, PR AUC: 0.8556, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0109
# ====> Epoch: 57 Average test Loss: 0.0182
# Fold 17 Results - Best Epoch: 57, Val Loss: 0.0109, Test Loss: 0.0182, Test AUC: 0.9028, PR AUC: 0.9093, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 54. Best Val Loss: 0.0119
# ====> Epoch: 54 Average test Loss: 0.0103
# Fold 18 Results - Best Epoch: 54, Val Loss: 0.0119, Test Loss: 0.0103, Test AUC: 0.8472, PR AUC: 0.9006, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0123
# ====> Epoch: 37 Average test Loss: 0.0142
# Fold 19 Results - Best Epoch: 37, Val Loss: 0.0123, Test Loss: 0.0142, Test AUC: 0.7500, PR AUC: 0.7801, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0183
# ====> Epoch: 11 Average test Loss: 0.0183
# Fold 20 Results - Best Epoch: 11, Val Loss: 0.0183, Test Loss: 0.0183, Test AUC: 0.4583, PR AUC: 0.5122, Accuracy: 0.5294
#
# Combination 2 Results:
# Mean Test Loss: 0.0161 ± 0.0041
# Mean Test AUC: 0.7130 ± 0.1507
# Mean Test PR AUC: 0.7416 ± 0.1398
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 3/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 8, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0148
# ====> Epoch: 30 Average test Loss: 0.0174
# Fold 1 Results - Best Epoch: 30, Val Loss: 0.0148, Test Loss: 0.0174, Test AUC: 0.6296, PR AUC: 0.5754, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 65. Best Val Loss: 0.0113
# ====> Epoch: 65 Average test Loss: 0.0221
# Fold 2 Results - Best Epoch: 65, Val Loss: 0.0113, Test Loss: 0.0221, Test AUC: 0.6296, PR AUC: 0.6301, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0140
# ====> Epoch: 36 Average test Loss: 0.0181
# Fold 3 Results - Best Epoch: 36, Val Loss: 0.0140, Test Loss: 0.0181, Test AUC: 0.8025, PR AUC: 0.8532, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 29. Best Val Loss: 0.0153
# ====> Epoch: 29 Average test Loss: 0.0141
# Fold 4 Results - Best Epoch: 29, Val Loss: 0.0153, Test Loss: 0.0141, Test AUC: 0.8750, PR AUC: 0.9182, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 63. Best Val Loss: 0.0109
# ====> Epoch: 63 Average test Loss: 0.0177
# Fold 5 Results - Best Epoch: 63, Val Loss: 0.0109, Test Loss: 0.0177, Test AUC: 0.8472, PR AUC: 0.8359, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0134
# ====> Epoch: 37 Average test Loss: 0.0137
# Fold 6 Results - Best Epoch: 37, Val Loss: 0.0134, Test Loss: 0.0137, Test AUC: 0.7361, PR AUC: 0.7705, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 80. Best Val Loss: 0.0117
# ====> Epoch: 80 Average test Loss: 0.0093
# Fold 7 Results - Best Epoch: 80, Val Loss: 0.0117, Test Loss: 0.0093, Test AUC: 0.9861, PR AUC: 0.9861, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0143
# ====> Epoch: 18 Average test Loss: 0.0163
# Fold 8 Results - Best Epoch: 18, Val Loss: 0.0143, Test Loss: 0.0163, Test AUC: 0.7917, PR AUC: 0.8527, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0119
# ====> Epoch: 52 Average test Loss: 0.0166
# Fold 9 Results - Best Epoch: 52, Val Loss: 0.0119, Test Loss: 0.0166, Test AUC: 0.7917, PR AUC: 0.7440, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 82. Best Val Loss: 0.0116
# ====> Epoch: 82 Average test Loss: 0.0200
# Fold 10 Results - Best Epoch: 82, Val Loss: 0.0116, Test Loss: 0.0200, Test AUC: 0.4722, PR AUC: 0.5082, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0142
# ====> Epoch: 44 Average test Loss: 0.0141
# Fold 11 Results - Best Epoch: 44, Val Loss: 0.0142, Test Loss: 0.0141, Test AUC: 0.6944, PR AUC: 0.6659, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 47. Best Val Loss: 0.0126
# ====> Epoch: 47 Average test Loss: 0.0197
# Fold 12 Results - Best Epoch: 47, Val Loss: 0.0126, Test Loss: 0.0197, Test AUC: 0.5972, PR AUC: 0.6344, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 102. Best Val Loss: 0.0116
# ====> Epoch: 102 Average test Loss: 0.0158
# Fold 13 Results - Best Epoch: 102, Val Loss: 0.0116, Test Loss: 0.0158, Test AUC: 0.8056, PR AUC: 0.7854, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0130
# ====> Epoch: 41 Average test Loss: 0.0138
# Fold 14 Results - Best Epoch: 41, Val Loss: 0.0130, Test Loss: 0.0138, Test AUC: 0.6250, PR AUC: 0.5954, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 48. Best Val Loss: 0.0140
# ====> Epoch: 48 Average test Loss: 0.0135
# Fold 15 Results - Best Epoch: 48, Val Loss: 0.0140, Test Loss: 0.0135, Test AUC: 0.7361, PR AUC: 0.7260, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0119
# ====> Epoch: 35 Average test Loss: 0.0147
# Fold 16 Results - Best Epoch: 35, Val Loss: 0.0119, Test Loss: 0.0147, Test AUC: 0.7500, PR AUC: 0.7804, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 93. Best Val Loss: 0.0111
# ====> Epoch: 93 Average test Loss: 0.0224
# Fold 17 Results - Best Epoch: 93, Val Loss: 0.0111, Test Loss: 0.0224, Test AUC: 0.7778, PR AUC: 0.7487, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 23. Best Val Loss: 0.0182
# ====> Epoch: 23 Average test Loss: 0.0193
# Fold 18 Results - Best Epoch: 23, Val Loss: 0.0182, Test Loss: 0.0193, Test AUC: 0.5000, PR AUC: 0.5294, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0140
# ====> Epoch: 36 Average test Loss: 0.0141
# Fold 19 Results - Best Epoch: 36, Val Loss: 0.0140, Test Loss: 0.0141, Test AUC: 0.7361, PR AUC: 0.7896, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0147
# ====> Epoch: 52 Average test Loss: 0.0148
# Fold 20 Results - Best Epoch: 52, Val Loss: 0.0147, Test Loss: 0.0148, Test AUC: 0.7708, PR AUC: 0.7735, Accuracy: 0.5294
#
# Combination 3 Results:
# Mean Test Loss: 0.0164 ± 0.0032
# Mean Test AUC: 0.7277 ± 0.1210
# Mean Test PR AUC: 0.7351 ± 0.1245
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 4/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 16, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0147
# ====> Epoch: 36 Average test Loss: 0.0149
# Fold 1 Results - Best Epoch: 36, Val Loss: 0.0147, Test Loss: 0.0149, Test AUC: 0.6420, PR AUC: 0.6409, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 68. Best Val Loss: 0.0098
# ====> Epoch: 68 Average test Loss: 0.0312
# Fold 2 Results - Best Epoch: 68, Val Loss: 0.0098, Test Loss: 0.0312, Test AUC: 0.6914, PR AUC: 0.7128, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 33. Best Val Loss: 0.0124
# ====> Epoch: 33 Average test Loss: 0.0205
# Fold 3 Results - Best Epoch: 33, Val Loss: 0.0124, Test Loss: 0.0205, Test AUC: 0.7160, PR AUC: 0.7213, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0133
# ====> Epoch: 35 Average test Loss: 0.0108
# Fold 4 Results - Best Epoch: 35, Val Loss: 0.0133, Test Loss: 0.0108, Test AUC: 0.8472, PR AUC: 0.8492, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 65. Best Val Loss: 0.0086
# ====> Epoch: 65 Average test Loss: 0.0131
# Fold 5 Results - Best Epoch: 65, Val Loss: 0.0086, Test Loss: 0.0131, Test AUC: 0.7222, PR AUC: 0.6353, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0124
# ====> Epoch: 43 Average test Loss: 0.0140
# Fold 6 Results - Best Epoch: 43, Val Loss: 0.0124, Test Loss: 0.0140, Test AUC: 0.8056, PR AUC: 0.8509, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 68. Best Val Loss: 0.0091
# ====> Epoch: 68 Average test Loss: 0.0065
# Fold 7 Results - Best Epoch: 68, Val Loss: 0.0091, Test Loss: 0.0065, Test AUC: 0.9167, PR AUC: 0.8318, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 49. Best Val Loss: 0.0111
# ====> Epoch: 49 Average test Loss: 0.0143
# Fold 8 Results - Best Epoch: 49, Val Loss: 0.0111, Test Loss: 0.0143, Test AUC: 0.7917, PR AUC: 0.8009, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0132
# ====> Epoch: 35 Average test Loss: 0.0128
# Fold 9 Results - Best Epoch: 35, Val Loss: 0.0132, Test Loss: 0.0128, Test AUC: 0.8333, PR AUC: 0.8373, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0132
# ====> Epoch: 38 Average test Loss: 0.0200
# Fold 10 Results - Best Epoch: 38, Val Loss: 0.0132, Test Loss: 0.0200, Test AUC: 0.5278, PR AUC: 0.6507, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 28. Best Val Loss: 0.0144
# ====> Epoch: 28 Average test Loss: 0.0168
# Fold 11 Results - Best Epoch: 28, Val Loss: 0.0144, Test Loss: 0.0168, Test AUC: 0.5694, PR AUC: 0.5683, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0135
# ====> Epoch: 39 Average test Loss: 0.0256
# Fold 12 Results - Best Epoch: 39, Val Loss: 0.0135, Test Loss: 0.0256, Test AUC: 0.5278, PR AUC: 0.6486, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0167
# ====> Epoch: 27 Average test Loss: 0.0152
# Fold 13 Results - Best Epoch: 27, Val Loss: 0.0167, Test Loss: 0.0152, Test AUC: 0.8333, PR AUC: 0.8623, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 61. Best Val Loss: 0.0104
# ====> Epoch: 61 Average test Loss: 0.0150
# Fold 14 Results - Best Epoch: 61, Val Loss: 0.0104, Test Loss: 0.0150, Test AUC: 0.7222, PR AUC: 0.6964, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0159
# ====> Epoch: 27 Average test Loss: 0.0135
# Fold 15 Results - Best Epoch: 27, Val Loss: 0.0159, Test Loss: 0.0135, Test AUC: 0.7778, PR AUC: 0.7865, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0132
# ====> Epoch: 39 Average test Loss: 0.0178
# Fold 16 Results - Best Epoch: 39, Val Loss: 0.0132, Test Loss: 0.0178, Test AUC: 0.9028, PR AUC: 0.9297, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0110
# ====> Epoch: 37 Average test Loss: 0.0208
# Fold 17 Results - Best Epoch: 37, Val Loss: 0.0110, Test Loss: 0.0208, Test AUC: 0.8264, PR AUC: 0.7790, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0115
# ====> Epoch: 30 Average test Loss: 0.0100
# Fold 18 Results - Best Epoch: 30, Val Loss: 0.0115, Test Loss: 0.0100, Test AUC: 0.8194, PR AUC: 0.7483, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0126
# ====> Epoch: 37 Average test Loss: 0.0171
# Fold 19 Results - Best Epoch: 37, Val Loss: 0.0126, Test Loss: 0.0171, Test AUC: 0.7917, PR AUC: 0.8651, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0115
# ====> Epoch: 41 Average test Loss: 0.0126
# Fold 20 Results - Best Epoch: 41, Val Loss: 0.0115, Test Loss: 0.0126, Test AUC: 0.8333, PR AUC: 0.8750, Accuracy: 0.5294
#
# Combination 4 Results:
# Mean Test Loss: 0.0161 ± 0.0054
# Mean Test AUC: 0.7549 ± 0.1114
# Mean Test PR AUC: 0.7645 ± 0.0980
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 5/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 16, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 29. Best Val Loss: 0.0148
# ====> Epoch: 29 Average test Loss: 0.0147
# Fold 1 Results - Best Epoch: 29, Val Loss: 0.0148, Test Loss: 0.0147, Test AUC: 0.7531, PR AUC: 0.7843, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 54. Best Val Loss: 0.0091
# ====> Epoch: 54 Average test Loss: 0.0223
# Fold 2 Results - Best Epoch: 54, Val Loss: 0.0091, Test Loss: 0.0223, Test AUC: 0.6543, PR AUC: 0.7057, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 26. Best Val Loss: 0.0139
# ====> Epoch: 26 Average test Loss: 0.0210
# Fold 3 Results - Best Epoch: 26, Val Loss: 0.0139, Test Loss: 0.0210, Test AUC: 0.7654, PR AUC: 0.8023, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 70. Best Val Loss: 0.0087
# ====> Epoch: 70 Average test Loss: 0.0088
# Fold 4 Results - Best Epoch: 70, Val Loss: 0.0087, Test Loss: 0.0088, Test AUC: 0.9167, PR AUC: 0.9160, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 61. Best Val Loss: 0.0112
# ====> Epoch: 61 Average test Loss: 0.0227
# Fold 5 Results - Best Epoch: 61, Val Loss: 0.0112, Test Loss: 0.0227, Test AUC: 0.5278, PR AUC: 0.4986, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 31. Best Val Loss: 0.0124
# ====> Epoch: 31 Average test Loss: 0.0129
# Fold 6 Results - Best Epoch: 31, Val Loss: 0.0124, Test Loss: 0.0129, Test AUC: 0.8750, PR AUC: 0.8726, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0084
# ====> Epoch: 52 Average test Loss: 0.0063
# Fold 7 Results - Best Epoch: 52, Val Loss: 0.0084, Test Loss: 0.0063, Test AUC: 1.0000, PR AUC: 1.0000, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 51. Best Val Loss: 0.0108
# ====> Epoch: 51 Average test Loss: 0.0149
# Fold 8 Results - Best Epoch: 51, Val Loss: 0.0108, Test Loss: 0.0149, Test AUC: 0.9306, PR AUC: 0.9294, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 20. Best Val Loss: 0.0131
# ====> Epoch: 20 Average test Loss: 0.0141
# Fold 9 Results - Best Epoch: 20, Val Loss: 0.0131, Test Loss: 0.0141, Test AUC: 0.7917, PR AUC: 0.8292, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0136
# ====> Epoch: 41 Average test Loss: 0.0197
# Fold 10 Results - Best Epoch: 41, Val Loss: 0.0136, Test Loss: 0.0197, Test AUC: 0.3333, PR AUC: 0.4495, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0121
# ====> Epoch: 43 Average test Loss: 0.0168
# Fold 11 Results - Best Epoch: 43, Val Loss: 0.0121, Test Loss: 0.0168, Test AUC: 0.5694, PR AUC: 0.5491, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 40. Best Val Loss: 0.0128
# ====> Epoch: 40 Average test Loss: 0.0215
# Fold 12 Results - Best Epoch: 40, Val Loss: 0.0128, Test Loss: 0.0215, Test AUC: 0.5903, PR AUC: 0.6158, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 20. Best Val Loss: 0.0169
# ====> Epoch: 20 Average test Loss: 0.0148
# Fold 13 Results - Best Epoch: 20, Val Loss: 0.0169, Test Loss: 0.0148, Test AUC: 0.9306, PR AUC: 0.9283, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 51. Best Val Loss: 0.0129
# ====> Epoch: 51 Average test Loss: 0.0134
# Fold 14 Results - Best Epoch: 51, Val Loss: 0.0129, Test Loss: 0.0134, Test AUC: 0.7083, PR AUC: 0.7329, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 32. Best Val Loss: 0.0131
# ====> Epoch: 32 Average test Loss: 0.0136
# Fold 15 Results - Best Epoch: 32, Val Loss: 0.0131, Test Loss: 0.0136, Test AUC: 0.7639, PR AUC: 0.7176, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0127
# ====> Epoch: 37 Average test Loss: 0.0126
# Fold 16 Results - Best Epoch: 37, Val Loss: 0.0127, Test Loss: 0.0126, Test AUC: 0.8750, PR AUC: 0.9014, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0103
# ====> Epoch: 57 Average test Loss: 0.0282
# Fold 17 Results - Best Epoch: 57, Val Loss: 0.0103, Test Loss: 0.0282, Test AUC: 0.9167, PR AUC: 0.9278, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 45. Best Val Loss: 0.0106
# ====> Epoch: 45 Average test Loss: 0.0086
# Fold 18 Results - Best Epoch: 45, Val Loss: 0.0106, Test Loss: 0.0086, Test AUC: 0.9167, PR AUC: 0.9192, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 41. Best Val Loss: 0.0133
# ====> Epoch: 41 Average test Loss: 0.0129
# Fold 19 Results - Best Epoch: 41, Val Loss: 0.0133, Test Loss: 0.0129, Test AUC: 0.7083, PR AUC: 0.7139, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0141
# ====> Epoch: 35 Average test Loss: 0.0143
# Fold 20 Results - Best Epoch: 35, Val Loss: 0.0141, Test Loss: 0.0143, Test AUC: 0.8472, PR AUC: 0.8790, Accuracy: 0.5294
#
# Combination 5 Results:
# Mean Test Loss: 0.0157 ± 0.0053
# Mean Test AUC: 0.7687 ± 0.1644
# Mean Test PR AUC: 0.7836 ± 0.1538
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 6/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.001, 'output_dim': 16, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0146
# ====> Epoch: 30 Average test Loss: 0.0163
# Fold 1 Results - Best Epoch: 30, Val Loss: 0.0146, Test Loss: 0.0163, Test AUC: 0.6296, PR AUC: 0.5986, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 49. Best Val Loss: 0.0121
# ====> Epoch: 49 Average test Loss: 0.0193
# Fold 2 Results - Best Epoch: 49, Val Loss: 0.0121, Test Loss: 0.0193, Test AUC: 0.6667, PR AUC: 0.7519, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 27. Best Val Loss: 0.0134
# ====> Epoch: 27 Average test Loss: 0.0196
# Fold 3 Results - Best Epoch: 27, Val Loss: 0.0134, Test Loss: 0.0196, Test AUC: 0.8025, PR AUC: 0.8315, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 96. Best Val Loss: 0.0111
# ====> Epoch: 96 Average test Loss: 0.0087
# Fold 4 Results - Best Epoch: 96, Val Loss: 0.0111, Test Loss: 0.0087, Test AUC: 0.9306, PR AUC: 0.9207, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 59. Best Val Loss: 0.0100
# ====> Epoch: 59 Average test Loss: 0.0133
# Fold 5 Results - Best Epoch: 59, Val Loss: 0.0100, Test Loss: 0.0133, Test AUC: 0.9028, PR AUC: 0.8994, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0127
# ====> Epoch: 37 Average test Loss: 0.0128
# Fold 6 Results - Best Epoch: 37, Val Loss: 0.0127, Test Loss: 0.0128, Test AUC: 0.7639, PR AUC: 0.7938, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 47. Best Val Loss: 0.0123
# ====> Epoch: 47 Average test Loss: 0.0088
# Fold 7 Results - Best Epoch: 47, Val Loss: 0.0123, Test Loss: 0.0088, Test AUC: 0.9861, PR AUC: 0.9861, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0108
# ====> Epoch: 57 Average test Loss: 0.0104
# Fold 8 Results - Best Epoch: 57, Val Loss: 0.0108, Test Loss: 0.0104, Test AUC: 0.8056, PR AUC: 0.6941, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0123
# ====> Epoch: 30 Average test Loss: 0.0135
# Fold 9 Results - Best Epoch: 30, Val Loss: 0.0123, Test Loss: 0.0135, Test AUC: 0.8750, PR AUC: 0.8896, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0131
# ====> Epoch: 44 Average test Loss: 0.0198
# Fold 10 Results - Best Epoch: 44, Val Loss: 0.0131, Test Loss: 0.0198, Test AUC: 0.4861, PR AUC: 0.5236, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 36. Best Val Loss: 0.0123
# ====> Epoch: 36 Average test Loss: 0.0153
# Fold 11 Results - Best Epoch: 36, Val Loss: 0.0123, Test Loss: 0.0153, Test AUC: 0.6250, PR AUC: 0.5944, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0139
# ====> Epoch: 43 Average test Loss: 0.0194
# Fold 12 Results - Best Epoch: 43, Val Loss: 0.0139, Test Loss: 0.0194, Test AUC: 0.5417, PR AUC: 0.5992, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 39. Best Val Loss: 0.0140
# ====> Epoch: 39 Average test Loss: 0.0164
# Fold 13 Results - Best Epoch: 39, Val Loss: 0.0140, Test Loss: 0.0164, Test AUC: 0.8472, PR AUC: 0.8623, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 52. Best Val Loss: 0.0134
# ====> Epoch: 52 Average test Loss: 0.0154
# Fold 14 Results - Best Epoch: 52, Val Loss: 0.0134, Test Loss: 0.0154, Test AUC: 0.7361, PR AUC: 0.6946, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 51. Best Val Loss: 0.0137
# ====> Epoch: 51 Average test Loss: 0.0118
# Fold 15 Results - Best Epoch: 51, Val Loss: 0.0137, Test Loss: 0.0118, Test AUC: 0.7917, PR AUC: 0.7946, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0130
# ====> Epoch: 37 Average test Loss: 0.0165
# Fold 16 Results - Best Epoch: 37, Val Loss: 0.0130, Test Loss: 0.0165, Test AUC: 0.7917, PR AUC: 0.8529, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 38. Best Val Loss: 0.0132
# ====> Epoch: 38 Average test Loss: 0.0238
# Fold 17 Results - Best Epoch: 38, Val Loss: 0.0132, Test Loss: 0.0238, Test AUC: 0.6528, PR AUC: 0.7043, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 43. Best Val Loss: 0.0116
# ====> Epoch: 43 Average test Loss: 0.0114
# Fold 18 Results - Best Epoch: 43, Val Loss: 0.0116, Test Loss: 0.0114, Test AUC: 0.8611, PR AUC: 0.8828, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 47. Best Val Loss: 0.0118
# ====> Epoch: 47 Average test Loss: 0.0132
# Fold 19 Results - Best Epoch: 47, Val Loss: 0.0118, Test Loss: 0.0132, Test AUC: 0.7778, PR AUC: 0.8056, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 37. Best Val Loss: 0.0152
# ====> Epoch: 37 Average test Loss: 0.0142
# Fold 20 Results - Best Epoch: 37, Val Loss: 0.0152, Test Loss: 0.0142, Test AUC: 0.7361, PR AUC: 0.7127, Accuracy: 0.5294
#
# Combination 6 Results:
# Mean Test Loss: 0.0150 ± 0.0039
# Mean Test AUC: 0.7605 ± 0.1259
# Mean Test PR AUC: 0.7696 ± 0.1233
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 7/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 8, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 105. Best Val Loss: 0.0162
# ====> Epoch: 105 Average test Loss: 0.0160
# Fold 1 Results - Best Epoch: 105, Val Loss: 0.0162, Test Loss: 0.0160, Test AUC: 0.6543, PR AUC: 0.7023, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 308. Best Val Loss: 0.0100
# ====> Epoch: 308 Average test Loss: 0.0185
# Fold 2 Results - Best Epoch: 308, Val Loss: 0.0100, Test Loss: 0.0185, Test AUC: 0.6914, PR AUC: 0.7890, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 225. Best Val Loss: 0.0131
# ====> Epoch: 225 Average test Loss: 0.0162
# Fold 3 Results - Best Epoch: 225, Val Loss: 0.0131, Test Loss: 0.0162, Test AUC: 0.8025, PR AUC: 0.8464, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 136. Best Val Loss: 0.0138
# ====> Epoch: 136 Average test Loss: 0.0119
# Fold 4 Results - Best Epoch: 136, Val Loss: 0.0138, Test Loss: 0.0119, Test AUC: 0.7500, PR AUC: 0.7801, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 123. Best Val Loss: 0.0129
# ====> Epoch: 123 Average test Loss: 0.0117
# Fold 5 Results - Best Epoch: 123, Val Loss: 0.0129, Test Loss: 0.0117, Test AUC: 0.8750, PR AUC: 0.8553, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 94. Best Val Loss: 0.0139
# ====> Epoch: 94 Average test Loss: 0.0143
# Fold 6 Results - Best Epoch: 94, Val Loss: 0.0139, Test Loss: 0.0143, Test AUC: 0.6944, PR AUC: 0.7578, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 190. Best Val Loss: 0.0093
# ====> Epoch: 190 Average test Loss: 0.0090
# Fold 7 Results - Best Epoch: 190, Val Loss: 0.0093, Test Loss: 0.0090, Test AUC: 0.9722, PR AUC: 0.9705, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 78. Best Val Loss: 0.0139
# ====> Epoch: 78 Average test Loss: 0.0179
# Fold 8 Results - Best Epoch: 78, Val Loss: 0.0139, Test Loss: 0.0179, Test AUC: 0.7778, PR AUC: 0.8235, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 147. Best Val Loss: 0.0133
# ====> Epoch: 147 Average test Loss: 0.0142
# Fold 9 Results - Best Epoch: 147, Val Loss: 0.0133, Test Loss: 0.0142, Test AUC: 0.9167, PR AUC: 0.9363, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 57. Best Val Loss: 0.0172
# ====> Epoch: 57 Average test Loss: 0.0172
# Fold 10 Results - Best Epoch: 57, Val Loss: 0.0172, Test Loss: 0.0172, Test AUC: 0.5000, PR AUC: 0.5801, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 63. Best Val Loss: 0.0148
# ====> Epoch: 63 Average test Loss: 0.0156
# Fold 11 Results - Best Epoch: 63, Val Loss: 0.0148, Test Loss: 0.0156, Test AUC: 0.5972, PR AUC: 0.5876, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 223. Best Val Loss: 0.0130
# ====> Epoch: 223 Average test Loss: 0.0171
# Fold 12 Results - Best Epoch: 223, Val Loss: 0.0130, Test Loss: 0.0171, Test AUC: 0.6111, PR AUC: 0.7325, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 196. Best Val Loss: 0.0118
# ====> Epoch: 196 Average test Loss: 0.0110
# Fold 13 Results - Best Epoch: 196, Val Loss: 0.0118, Test Loss: 0.0110, Test AUC: 0.9028, PR AUC: 0.9237, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0181
# ====> Epoch: 11 Average test Loss: 0.0199
# Fold 14 Results - Best Epoch: 11, Val Loss: 0.0181, Test Loss: 0.0199, Test AUC: 0.2500, PR AUC: 0.4218, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 133. Best Val Loss: 0.0163
# ====> Epoch: 133 Average test Loss: 0.0149
# Fold 15 Results - Best Epoch: 133, Val Loss: 0.0163, Test Loss: 0.0149, Test AUC: 0.7083, PR AUC: 0.7589, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 117. Best Val Loss: 0.0122
# ====> Epoch: 117 Average test Loss: 0.0156
# Fold 16 Results - Best Epoch: 117, Val Loss: 0.0122, Test Loss: 0.0156, Test AUC: 0.8056, PR AUC: 0.8209, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 255. Best Val Loss: 0.0093
# ====> Epoch: 255 Average test Loss: 0.0168
# Fold 17 Results - Best Epoch: 255, Val Loss: 0.0093, Test Loss: 0.0168, Test AUC: 0.9306, PR AUC: 0.9460, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0185
# Fold 18 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0185, Test AUC: 0.6528, PR AUC: 0.7826, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 145. Best Val Loss: 0.0140
# ====> Epoch: 145 Average test Loss: 0.0141
# Fold 19 Results - Best Epoch: 145, Val Loss: 0.0140, Test Loss: 0.0141, Test AUC: 0.7083, PR AUC: 0.7802, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 16. Best Val Loss: 0.0182
# ====> Epoch: 16 Average test Loss: 0.0189
# Fold 20 Results - Best Epoch: 16, Val Loss: 0.0182, Test Loss: 0.0189, Test AUC: 0.5000, PR AUC: 0.5705, Accuracy: 0.5294
#
# Combination 7 Results:
# Mean Test Loss: 0.0155 ± 0.0028
# Mean Test AUC: 0.7150 ± 0.1699
# Mean Test PR AUC: 0.7683 ± 0.1375
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 8/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 8, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 142. Best Val Loss: 0.0137
# ====> Epoch: 142 Average test Loss: 0.0158
# Fold 1 Results - Best Epoch: 142, Val Loss: 0.0137, Test Loss: 0.0158, Test AUC: 0.6420, PR AUC: 0.5933, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 141. Best Val Loss: 0.0133
# ====> Epoch: 141 Average test Loss: 0.0168
# Fold 2 Results - Best Epoch: 141, Val Loss: 0.0133, Test Loss: 0.0168, Test AUC: 0.6790, PR AUC: 0.6774, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 102. Best Val Loss: 0.0136
# ====> Epoch: 102 Average test Loss: 0.0185
# Fold 3 Results - Best Epoch: 102, Val Loss: 0.0136, Test Loss: 0.0185, Test AUC: 0.7531, PR AUC: 0.8185, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 201. Best Val Loss: 0.0148
# ====> Epoch: 201 Average test Loss: 0.0130
# Fold 4 Results - Best Epoch: 201, Val Loss: 0.0148, Test Loss: 0.0130, Test AUC: 0.8472, PR AUC: 0.8678, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 121. Best Val Loss: 0.0134
# ====> Epoch: 121 Average test Loss: 0.0128
# Fold 5 Results - Best Epoch: 121, Val Loss: 0.0134, Test Loss: 0.0128, Test AUC: 0.8611, PR AUC: 0.8513, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 96. Best Val Loss: 0.0137
# ====> Epoch: 96 Average test Loss: 0.0142
# Fold 6 Results - Best Epoch: 96, Val Loss: 0.0137, Test Loss: 0.0142, Test AUC: 0.7361, PR AUC: 0.7704, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 278. Best Val Loss: 0.0096
# ====> Epoch: 278 Average test Loss: 0.0095
# Fold 7 Results - Best Epoch: 278, Val Loss: 0.0096, Test Loss: 0.0095, Test AUC: 0.9861, PR AUC: 0.9861, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 104. Best Val Loss: 0.0147
# ====> Epoch: 104 Average test Loss: 0.0157
# Fold 8 Results - Best Epoch: 104, Val Loss: 0.0147, Test Loss: 0.0157, Test AUC: 0.7778, PR AUC: 0.8505, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 129. Best Val Loss: 0.0145
# ====> Epoch: 129 Average test Loss: 0.0132
# Fold 9 Results - Best Epoch: 129, Val Loss: 0.0145, Test Loss: 0.0132, Test AUC: 0.8611, PR AUC: 0.8832, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 138. Best Val Loss: 0.0145
# ====> Epoch: 138 Average test Loss: 0.0175
# Fold 10 Results - Best Epoch: 138, Val Loss: 0.0145, Test Loss: 0.0175, Test AUC: 0.4861, PR AUC: 0.6399, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 166. Best Val Loss: 0.0130
# ====> Epoch: 166 Average test Loss: 0.0205
# Fold 11 Results - Best Epoch: 166, Val Loss: 0.0130, Test Loss: 0.0205, Test AUC: 0.5139, PR AUC: 0.5377, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 51. Best Val Loss: 0.0175
# ====> Epoch: 51 Average test Loss: 0.0196
# Fold 12 Results - Best Epoch: 51, Val Loss: 0.0175, Test Loss: 0.0196, Test AUC: 0.4167, PR AUC: 0.5140, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 113. Best Val Loss: 0.0145
# ====> Epoch: 113 Average test Loss: 0.0124
# Fold 13 Results - Best Epoch: 113, Val Loss: 0.0145, Test Loss: 0.0124, Test AUC: 0.8472, PR AUC: 0.8409, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0183
# ====> Epoch: 12 Average test Loss: 0.0197
# Fold 14 Results - Best Epoch: 12, Val Loss: 0.0183, Test Loss: 0.0197, Test AUC: 0.3889, PR AUC: 0.4745, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 136. Best Val Loss: 0.0144
# ====> Epoch: 136 Average test Loss: 0.0146
# Fold 15 Results - Best Epoch: 136, Val Loss: 0.0144, Test Loss: 0.0146, Test AUC: 0.7222, PR AUC: 0.7599, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 170. Best Val Loss: 0.0121
# ====> Epoch: 170 Average test Loss: 0.0146
# Fold 16 Results - Best Epoch: 170, Val Loss: 0.0121, Test Loss: 0.0146, Test AUC: 0.8611, PR AUC: 0.8895, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 198. Best Val Loss: 0.0105
# ====> Epoch: 198 Average test Loss: 0.0197
# Fold 17 Results - Best Epoch: 198, Val Loss: 0.0105, Test Loss: 0.0197, Test AUC: 0.8889, PR AUC: 0.8985, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 98. Best Val Loss: 0.0141
# ====> Epoch: 98 Average test Loss: 0.0138
# Fold 18 Results - Best Epoch: 98, Val Loss: 0.0141, Test Loss: 0.0138, Test AUC: 0.7361, PR AUC: 0.7434, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0209
# Fold 19 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0209, Test AUC: 0.2917, PR AUC: 0.4465, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 176. Best Val Loss: 0.0134
# ====> Epoch: 176 Average test Loss: 0.0099
# Fold 20 Results - Best Epoch: 176, Val Loss: 0.0134, Test Loss: 0.0099, Test AUC: 0.9028, PR AUC: 0.9381, Accuracy: 0.5294
#
# Combination 8 Results:
# Mean Test Loss: 0.0156 ± 0.0033
# Mean Test AUC: 0.7100 ± 0.1895
# Mean Test PR AUC: 0.7491 ± 0.1595
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 9/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 8, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 109. Best Val Loss: 0.0155
# ====> Epoch: 109 Average test Loss: 0.0149
# Fold 1 Results - Best Epoch: 109, Val Loss: 0.0155, Test Loss: 0.0149, Test AUC: 0.6420, PR AUC: 0.5979, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0184
# ====> Epoch: 11 Average test Loss: 0.0181
# Fold 2 Results - Best Epoch: 11, Val Loss: 0.0184, Test Loss: 0.0181, Test AUC: 0.4321, PR AUC: 0.4713, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 147. Best Val Loss: 0.0128
# ====> Epoch: 147 Average test Loss: 0.0174
# Fold 3 Results - Best Epoch: 147, Val Loss: 0.0128, Test Loss: 0.0174, Test AUC: 0.8519, PR AUC: 0.8715, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 233. Best Val Loss: 0.0114
# ====> Epoch: 233 Average test Loss: 0.0090
# Fold 4 Results - Best Epoch: 233, Val Loss: 0.0114, Test Loss: 0.0090, Test AUC: 0.9861, PR AUC: 0.9861, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 124. Best Val Loss: 0.0182
# ====> Epoch: 124 Average test Loss: 0.0196
# Fold 5 Results - Best Epoch: 124, Val Loss: 0.0182, Test Loss: 0.0196, Test AUC: 0.5000, PR AUC: 0.4706, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 159. Best Val Loss: 0.0118
# ====> Epoch: 159 Average test Loss: 0.0140
# Fold 6 Results - Best Epoch: 159, Val Loss: 0.0118, Test Loss: 0.0140, Test AUC: 0.7361, PR AUC: 0.7907, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 218. Best Val Loss: 0.0105
# ====> Epoch: 218 Average test Loss: 0.0089
# Fold 7 Results - Best Epoch: 218, Val Loss: 0.0105, Test Loss: 0.0089, Test AUC: 1.0000, PR AUC: 1.0000, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 114. Best Val Loss: 0.0136
# ====> Epoch: 114 Average test Loss: 0.0124
# Fold 8 Results - Best Epoch: 114, Val Loss: 0.0136, Test Loss: 0.0124, Test AUC: 0.8611, PR AUC: 0.9010, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 16. Best Val Loss: 0.0181
# ====> Epoch: 16 Average test Loss: 0.0192
# Fold 9 Results - Best Epoch: 16, Val Loss: 0.0181, Test Loss: 0.0192, Test AUC: 0.6806, PR AUC: 0.7108, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 120. Best Val Loss: 0.0146
# ====> Epoch: 120 Average test Loss: 0.0185
# Fold 10 Results - Best Epoch: 120, Val Loss: 0.0146, Test Loss: 0.0185, Test AUC: 0.4722, PR AUC: 0.5518, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 167. Best Val Loss: 0.0134
# ====> Epoch: 167 Average test Loss: 0.0162
# Fold 11 Results - Best Epoch: 167, Val Loss: 0.0134, Test Loss: 0.0162, Test AUC: 0.6667, PR AUC: 0.6177, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 45. Best Val Loss: 0.0176
# ====> Epoch: 45 Average test Loss: 0.0181
# Fold 12 Results - Best Epoch: 45, Val Loss: 0.0176, Test Loss: 0.0181, Test AUC: 0.4722, PR AUC: 0.5928, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0182
# ====> Epoch: 12 Average test Loss: 0.0194
# Fold 13 Results - Best Epoch: 12, Val Loss: 0.0182, Test Loss: 0.0194, Test AUC: 0.5139, PR AUC: 0.5573, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 137. Best Val Loss: 0.0156
# ====> Epoch: 137 Average test Loss: 0.0138
# Fold 14 Results - Best Epoch: 137, Val Loss: 0.0156, Test Loss: 0.0138, Test AUC: 0.7361, PR AUC: 0.7341, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 119. Best Val Loss: 0.0140
# ====> Epoch: 119 Average test Loss: 0.0143
# Fold 15 Results - Best Epoch: 119, Val Loss: 0.0140, Test Loss: 0.0143, Test AUC: 0.6389, PR AUC: 0.6270, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 130. Best Val Loss: 0.0126
# ====> Epoch: 130 Average test Loss: 0.0187
# Fold 16 Results - Best Epoch: 130, Val Loss: 0.0126, Test Loss: 0.0187, Test AUC: 0.6806, PR AUC: 0.7426, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 75. Best Val Loss: 0.0141
# ====> Epoch: 75 Average test Loss: 0.0194
# Fold 17 Results - Best Epoch: 75, Val Loss: 0.0141, Test Loss: 0.0194, Test AUC: 0.6250, PR AUC: 0.7890, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 184. Best Val Loss: 0.0104
# ====> Epoch: 184 Average test Loss: 0.0087
# Fold 18 Results - Best Epoch: 184, Val Loss: 0.0104, Test Loss: 0.0087, Test AUC: 0.9722, PR AUC: 0.9765, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 91. Best Val Loss: 0.0158
# ====> Epoch: 91 Average test Loss: 0.0137
# Fold 19 Results - Best Epoch: 91, Val Loss: 0.0158, Test Loss: 0.0137, Test AUC: 0.7778, PR AUC: 0.8716, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 96. Best Val Loss: 0.0170
# ====> Epoch: 96 Average test Loss: 0.0157
# Fold 20 Results - Best Epoch: 96, Val Loss: 0.0170, Test Loss: 0.0157, Test AUC: 0.6250, PR AUC: 0.7276, Accuracy: 0.5294
#
# Combination 9 Results:
# Mean Test Loss: 0.0155 ± 0.0035
# Mean Test AUC: 0.6935 ± 0.1693
# Mean Test PR AUC: 0.7294 ± 0.1630
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 10/24 =====
# Parameters: {'batch_size': 8, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0182
# ====> Epoch: 14 Average test Loss: 0.0191
# Fold 1 Results - Best Epoch: 14, Val Loss: 0.0182, Test Loss: 0.0191, Test AUC: 0.3827, PR AUC: 0.5245, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 229. Best Val Loss: 0.0113
# ====> Epoch: 229 Average test Loss: 0.0180
# Fold 2 Results - Best Epoch: 229, Val Loss: 0.0113, Test Loss: 0.0180, Test AUC: 0.5802, PR AUC: 0.5985, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 97. Best Val Loss: 0.0140
# ====> Epoch: 97 Average test Loss: 0.0181
# Fold 3 Results - Best Epoch: 97, Val Loss: 0.0140, Test Loss: 0.0181, Test AUC: 0.8025, PR AUC: 0.8324, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 152. Best Val Loss: 0.0134
# ====> Epoch: 152 Average test Loss: 0.0101
# Fold 4 Results - Best Epoch: 152, Val Loss: 0.0134, Test Loss: 0.0101, Test AUC: 0.8611, PR AUC: 0.8742, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 162. Best Val Loss: 0.0110
# ====> Epoch: 162 Average test Loss: 0.0155
# ...
# Early stopping triggered at epoch 15. Best Val Loss: 0.0172
# ====> Epoch: 15 Average test Loss: 0.0223
# Fold 20 Results - Best Epoch: 15, Val Loss: 0.0172, Test Loss: 0.0223, Test AUC: 0.3056, PR AUC: 0.4440, Accuracy: 0.5294
#
# Combination 21 Results:
# Mean Test Loss: 0.0209 ± 0.0030
# Mean Test AUC: 0.5258 ± 0.1858
# Mean Test PR AUC: 0.6085 ± 0.1359
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 22/24 =====
# Parameters: {'batch_size': 16, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 1e-06}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 65. Best Val Loss: 0.0168
# ====> Epoch: 65 Average test Loss: 0.0161
# Fold 1 Results - Best Epoch: 65, Val Loss: 0.0168, Test Loss: 0.0161, Test AUC: 0.7037, PR AUC: 0.6880, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0182
# ====> Epoch: 12 Average test Loss: 0.0227
# Fold 2 Results - Best Epoch: 12, Val Loss: 0.0182, Test Loss: 0.0227, Test AUC: 0.3333, PR AUC: 0.4459, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 138. Best Val Loss: 0.0119
# ====> Epoch: 138 Average test Loss: 0.0241
# Fold 3 Results - Best Epoch: 138, Val Loss: 0.0119, Test Loss: 0.0241, Test AUC: 0.6790, PR AUC: 0.7227, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 122. Best Val Loss: 0.0142
# ====> Epoch: 122 Average test Loss: 0.0118
# Fold 4 Results - Best Epoch: 122, Val Loss: 0.0142, Test Loss: 0.0118, Test AUC: 0.7639, PR AUC: 0.8073, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0177
# ====> Epoch: 11 Average test Loss: 0.0231
# Fold 5 Results - Best Epoch: 11, Val Loss: 0.0177, Test Loss: 0.0231, Test AUC: 0.4028, PR AUC: 0.4774, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0178
# ====> Epoch: 11 Average test Loss: 0.0201
# Fold 6 Results - Best Epoch: 11, Val Loss: 0.0178, Test Loss: 0.0201, Test AUC: 0.7222, PR AUC: 0.7083, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0182
# ====> Epoch: 12 Average test Loss: 0.0248
# Fold 7 Results - Best Epoch: 12, Val Loss: 0.0182, Test Loss: 0.0248, Test AUC: 0.5278, PR AUC: 0.5353, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 108. Best Val Loss: 0.0137
# ====> Epoch: 108 Average test Loss: 0.0203
# Fold 8 Results - Best Epoch: 108, Val Loss: 0.0137, Test Loss: 0.0203, Test AUC: 0.7917, PR AUC: 0.8479, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0176
# ====> Epoch: 11 Average test Loss: 0.0228
# Fold 9 Results - Best Epoch: 11, Val Loss: 0.0176, Test Loss: 0.0228, Test AUC: 0.5694, PR AUC: 0.6354, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 44. Best Val Loss: 0.0181
# ====> Epoch: 44 Average test Loss: 0.0179
# Fold 10 Results - Best Epoch: 44, Val Loss: 0.0181, Test Loss: 0.0179, Test AUC: 0.5694, PR AUC: 0.5810, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0181
# ====> Epoch: 11 Average test Loss: 0.0207
# Fold 11 Results - Best Epoch: 11, Val Loss: 0.0181, Test Loss: 0.0207, Test AUC: 0.5417, PR AUC: 0.6764, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0183
# ====> Epoch: 11 Average test Loss: 0.0191
# Fold 12 Results - Best Epoch: 11, Val Loss: 0.0183, Test Loss: 0.0191, Test AUC: 0.3194, PR AUC: 0.4480, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0185
# ====> Epoch: 18 Average test Loss: 0.0180
# Fold 13 Results - Best Epoch: 18, Val Loss: 0.0185, Test Loss: 0.0180, Test AUC: 0.4583, PR AUC: 0.5211, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0183
# ====> Epoch: 11 Average test Loss: 0.0199
# Fold 14 Results - Best Epoch: 11, Val Loss: 0.0183, Test Loss: 0.0199, Test AUC: 0.3194, PR AUC: 0.4466, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 30. Best Val Loss: 0.0183
# ====> Epoch: 30 Average test Loss: 0.0174
# Fold 15 Results - Best Epoch: 30, Val Loss: 0.0183, Test Loss: 0.0174, Test AUC: 0.4861, PR AUC: 0.5475, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 203. Best Val Loss: 0.0113
# ====> Epoch: 203 Average test Loss: 0.0080
# Fold 16 Results - Best Epoch: 203, Val Loss: 0.0113, Test Loss: 0.0080, Test AUC: 0.8056, PR AUC: 0.7364, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0205
# Fold 17 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0205, Test AUC: 0.5556, PR AUC: 0.6401, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0174
# ====> Epoch: 11 Average test Loss: 0.0217
# Fold 18 Results - Best Epoch: 11, Val Loss: 0.0174, Test Loss: 0.0217, Test AUC: 0.4583, PR AUC: 0.5005, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0172
# ====> Epoch: 11 Average test Loss: 0.0246
# Fold 19 Results - Best Epoch: 11, Val Loss: 0.0172, Test Loss: 0.0246, Test AUC: 0.4167, PR AUC: 0.5471, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0186
# ====> Epoch: 11 Average test Loss: 0.0181
# Fold 20 Results - Best Epoch: 11, Val Loss: 0.0186, Test Loss: 0.0181, Test AUC: 0.5139, PR AUC: 0.5859, Accuracy: 0.5294
#
# Combination 22 Results:
# Mean Test Loss: 0.0196 ± 0.0041
# Mean Test AUC: 0.5469 ± 0.1509
# Mean Test PR AUC: 0.6050 ± 0.1178
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 23/24 =====
# Parameters: {'batch_size': 16, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 1e-05}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0178
# ====> Epoch: 14 Average test Loss: 0.0224
# Fold 1 Results - Best Epoch: 14, Val Loss: 0.0178, Test Loss: 0.0224, Test AUC: 0.4321, PR AUC: 0.4866, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0230
# Fold 2 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0230, Test AUC: 0.3704, PR AUC: 0.5355, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0177
# ====> Epoch: 11 Average test Loss: 0.0226
# Fold 3 Results - Best Epoch: 11, Val Loss: 0.0177, Test Loss: 0.0226, Test AUC: 0.2469, PR AUC: 0.4016, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0177
# ====> Epoch: 11 Average test Loss: 0.0203
# Fold 4 Results - Best Epoch: 11, Val Loss: 0.0177, Test Loss: 0.0203, Test AUC: 0.4028, PR AUC: 0.4359, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 15. Best Val Loss: 0.0178
# ====> Epoch: 15 Average test Loss: 0.0236
# Fold 5 Results - Best Epoch: 15, Val Loss: 0.0178, Test Loss: 0.0236, Test AUC: 0.3889, PR AUC: 0.5350, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0183
# ====> Epoch: 11 Average test Loss: 0.0198
# Fold 6 Results - Best Epoch: 11, Val Loss: 0.0183, Test Loss: 0.0198, Test AUC: 0.4028, PR AUC: 0.5715, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0175
# ====> Epoch: 12 Average test Loss: 0.0211
# Fold 7 Results - Best Epoch: 12, Val Loss: 0.0175, Test Loss: 0.0211, Test AUC: 0.4583, PR AUC: 0.4495, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0196
# Fold 8 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0196, Test AUC: 0.5556, PR AUC: 0.5372, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0172
# ====> Epoch: 14 Average test Loss: 0.0238
# Fold 9 Results - Best Epoch: 14, Val Loss: 0.0172, Test Loss: 0.0238, Test AUC: 0.5139, PR AUC: 0.6104, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0179
# ====> Epoch: 12 Average test Loss: 0.0232
# Fold 10 Results - Best Epoch: 12, Val Loss: 0.0179, Test Loss: 0.0232, Test AUC: 0.4028, PR AUC: 0.5760, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0231
# Fold 11 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0231, Test AUC: 0.4583, PR AUC: 0.6297, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0180
# ====> Epoch: 11 Average test Loss: 0.0194
# Fold 12 Results - Best Epoch: 11, Val Loss: 0.0180, Test Loss: 0.0194, Test AUC: 0.3472, PR AUC: 0.5299, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 17. Best Val Loss: 0.0183
# ====> Epoch: 17 Average test Loss: 0.0179
# Fold 13 Results - Best Epoch: 17, Val Loss: 0.0183, Test Loss: 0.0179, Test AUC: 0.6944, PR AUC: 0.6287, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 26. Best Val Loss: 0.0185
# ====> Epoch: 26 Average test Loss: 0.0177
# Fold 14 Results - Best Epoch: 26, Val Loss: 0.0185, Test Loss: 0.0177, Test AUC: 0.5556, PR AUC: 0.6288, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0180
# ====> Epoch: 14 Average test Loss: 0.0251
# Fold 15 Results - Best Epoch: 14, Val Loss: 0.0180, Test Loss: 0.0251, Test AUC: 0.3750, PR AUC: 0.5077, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 190. Best Val Loss: 0.0109
# ====> Epoch: 190 Average test Loss: 0.0146
# Fold 16 Results - Best Epoch: 190, Val Loss: 0.0109, Test Loss: 0.0146, Test AUC: 0.8889, PR AUC: 0.9122, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0184
# ====> Epoch: 12 Average test Loss: 0.0223
# Fold 17 Results - Best Epoch: 12, Val Loss: 0.0184, Test Loss: 0.0223, Test AUC: 0.4861, PR AUC: 0.6343, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 13. Best Val Loss: 0.0186
# ====> Epoch: 13 Average test Loss: 0.0239
# Fold 18 Results - Best Epoch: 13, Val Loss: 0.0186, Test Loss: 0.0239, Test AUC: 0.4722, PR AUC: 0.6114, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0173
# ====> Epoch: 11 Average test Loss: 0.0239
# Fold 19 Results - Best Epoch: 11, Val Loss: 0.0173, Test Loss: 0.0239, Test AUC: 0.3056, PR AUC: 0.5088, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0175
# ====> Epoch: 11 Average test Loss: 0.0223
# Fold 20 Results - Best Epoch: 11, Val Loss: 0.0175, Test Loss: 0.0223, Test AUC: 0.6944, PR AUC: 0.7668, Accuracy: 0.5294
#
# Combination 23 Results:
# Mean Test Loss: 0.0215 ± 0.0026
# Mean Test AUC: 0.4726 ± 0.1459
# Mean Test PR AUC: 0.5749 ± 0.1127
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# ===== Evaluating Hyperparameter Combination 24/24 =====
# Parameters: {'batch_size': 16, 'dropout': 0.2, 'lr': 0.0001, 'output_dim': 16, 'wd': 0.0001}
#
# --- Fold 1/20 ---
# Early stopping triggered at epoch 35. Best Val Loss: 0.0179
# ====> Epoch: 35 Average test Loss: 0.0167
# Fold 1 Results - Best Epoch: 35, Val Loss: 0.0179, Test Loss: 0.0167, Test AUC: 0.6049, PR AUC: 0.5732, Accuracy: 0.5000
#
# --- Fold 2/20 ---
# Early stopping triggered at epoch 171. Best Val Loss: 0.0126
# ====> Epoch: 171 Average test Loss: 0.0153
# Fold 2 Results - Best Epoch: 171, Val Loss: 0.0126, Test Loss: 0.0153, Test AUC: 0.6296, PR AUC: 0.6806, Accuracy: 0.5000
#
# --- Fold 3/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0190
# Fold 3 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0190, Test AUC: 0.6049, PR AUC: 0.6387, Accuracy: 0.5000
#
# --- Fold 4/20 ---
# Early stopping triggered at epoch 13. Best Val Loss: 0.0179
# ====> Epoch: 13 Average test Loss: 0.0217
# Fold 4 Results - Best Epoch: 13, Val Loss: 0.0179, Test Loss: 0.0217, Test AUC: 0.4167, PR AUC: 0.4531, Accuracy: 0.4706
#
# --- Fold 5/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0177
# ====> Epoch: 12 Average test Loss: 0.0231
# Fold 5 Results - Best Epoch: 12, Val Loss: 0.0177, Test Loss: 0.0231, Test AUC: 0.3889, PR AUC: 0.4463, Accuracy: 0.4706
#
# --- Fold 6/20 ---
# Early stopping triggered at epoch 120. Best Val Loss: 0.0138
# ====> Epoch: 120 Average test Loss: 0.0133
# Fold 6 Results - Best Epoch: 120, Val Loss: 0.0138, Test Loss: 0.0133, Test AUC: 0.7083, PR AUC: 0.7510, Accuracy: 0.4706
#
# --- Fold 7/20 ---
# Early stopping triggered at epoch 18. Best Val Loss: 0.0184
# ====> Epoch: 18 Average test Loss: 0.0183
# Fold 7 Results - Best Epoch: 18, Val Loss: 0.0184, Test Loss: 0.0183, Test AUC: 0.6944, PR AUC: 0.7371, Accuracy: 0.4706
#
# --- Fold 8/20 ---
# Early stopping triggered at epoch 16. Best Val Loss: 0.0180
# ====> Epoch: 16 Average test Loss: 0.0233
# Fold 8 Results - Best Epoch: 16, Val Loss: 0.0180, Test Loss: 0.0233, Test AUC: 0.5278, PR AUC: 0.6196, Accuracy: 0.4706
#
# --- Fold 9/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0174
# ====> Epoch: 11 Average test Loss: 0.0224
# Fold 9 Results - Best Epoch: 11, Val Loss: 0.0174, Test Loss: 0.0224, Test AUC: 0.5833, PR AUC: 0.6215, Accuracy: 0.4706
#
# --- Fold 10/20 ---
# Early stopping triggered at epoch 13. Best Val Loss: 0.0183
# ====> Epoch: 13 Average test Loss: 0.0178
# Fold 10 Results - Best Epoch: 13, Val Loss: 0.0183, Test Loss: 0.0178, Test AUC: 0.4444, PR AUC: 0.5714, Accuracy: 0.5294
#
# --- Fold 11/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0181
# ====> Epoch: 12 Average test Loss: 0.0238
# Fold 11 Results - Best Epoch: 12, Val Loss: 0.0181, Test Loss: 0.0238, Test AUC: 0.4583, PR AUC: 0.5355, Accuracy: 0.5294
#
# --- Fold 12/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0181
# ====> Epoch: 14 Average test Loss: 0.0214
# Fold 12 Results - Best Epoch: 14, Val Loss: 0.0181, Test Loss: 0.0214, Test AUC: 0.3472, PR AUC: 0.5475, Accuracy: 0.5294
#
# --- Fold 13/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0211
# Fold 13 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0211, Test AUC: 0.3056, PR AUC: 0.4443, Accuracy: 0.5294
#
# --- Fold 14/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0182
# ====> Epoch: 11 Average test Loss: 0.0183
# Fold 14 Results - Best Epoch: 11, Val Loss: 0.0182, Test Loss: 0.0183, Test AUC: 0.4444, PR AUC: 0.5113, Accuracy: 0.5294
#
# --- Fold 15/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0178
# ====> Epoch: 11 Average test Loss: 0.0249
# Fold 15 Results - Best Epoch: 11, Val Loss: 0.0178, Test Loss: 0.0249, Test AUC: 0.2639, PR AUC: 0.4293, Accuracy: 0.5294
#
# --- Fold 16/20 ---
# Early stopping triggered at epoch 187. Best Val Loss: 0.0115
# ====> Epoch: 187 Average test Loss: 0.0145
# Fold 16 Results - Best Epoch: 187, Val Loss: 0.0115, Test Loss: 0.0145, Test AUC: 0.8750, PR AUC: 0.9083, Accuracy: 0.5294
#
# --- Fold 17/20 ---
# Early stopping triggered at epoch 12. Best Val Loss: 0.0183
# ====> Epoch: 12 Average test Loss: 0.0230
# Fold 17 Results - Best Epoch: 12, Val Loss: 0.0183, Test Loss: 0.0230, Test AUC: 0.5694, PR AUC: 0.6655, Accuracy: 0.5294
#
# --- Fold 18/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0188
# ====> Epoch: 11 Average test Loss: 0.0241
# Fold 18 Results - Best Epoch: 11, Val Loss: 0.0188, Test Loss: 0.0241, Test AUC: 0.4167, PR AUC: 0.5477, Accuracy: 0.5294
#
# --- Fold 19/20 ---
# Early stopping triggered at epoch 14. Best Val Loss: 0.0175
# ====> Epoch: 14 Average test Loss: 0.0247
# Fold 19 Results - Best Epoch: 14, Val Loss: 0.0175, Test Loss: 0.0247, Test AUC: 0.3889, PR AUC: 0.5377, Accuracy: 0.5294
#
# --- Fold 20/20 ---
# Early stopping triggered at epoch 11. Best Val Loss: 0.0176
# ====> Epoch: 11 Average test Loss: 0.0208
# Fold 20 Results - Best Epoch: 11, Val Loss: 0.0176, Test Loss: 0.0208, Test AUC: 0.1944, PR AUC: 0.4767, Accuracy: 0.5294
#
# Combination 24 Results:
# Mean Test Loss: 0.0204 ± 0.0034
# Mean Test AUC: 0.4934 ± 0.1626
# Mean Test PR AUC: 0.5848 ± 0.1187
# Mean Test Accuracy: 0.5074 ± 0.0261
#
# Grid search completed. Results saved to single mgl grid_search_results.csv
